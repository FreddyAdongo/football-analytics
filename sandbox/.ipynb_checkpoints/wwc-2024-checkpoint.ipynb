# %%
from statsbombpy import sb
import pandas as pd
import numpy as np

# %%
sb.competitions()
# Out:
# C:\Users\fredd\anaconda3\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# ...

# %%
sb.matches(competition_id=72,season_id=107)
# Out:
# C:\Users\fredd\anaconda3\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off                        competition  \
# 0    3904629  2023-08-16  13:00:00.000  International - Women's World Cup
# 1    3906390  2023-08-20  13:00:00.000  International - Women's World Cup
# 2    3906389  2023-08-19  11:00:00.000  International - Women's World Cup
# 3    3904628  2023-08-15  11:00:00.000  International - Women's World Cup
# 4    3893806  2023-07-26  10:30:00.000  International - Women's World Cup
# ..       ...         ...           ...                                ...
# 59   3893800  2023-07-24  09:00:00.000  International - Women's World Cup
# 60   3893799  2023-07-24  11:30:00.000  International - Women's World Cup
# 61   3893796  2023-07-23  08:00:00.000  International - Women's World Cup
# ...

# %%
df = sb.events(match_id=3893833)
# Out:
# C:\Users\fredd\anaconda3\Lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
df
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 0      NaN                  NaN                            NaN
# 1      NaN                  NaN                            NaN
# 2      NaN                  NaN                            NaN
# 3      NaN                  NaN                            NaN
# 4      NaN                  NaN                            NaN
# ...    ...                  ...                            ...
# 3267   NaN                  NaN                            NaN
# 3268   NaN                  NaN                            NaN
# 3269   NaN                  NaN                            NaN
# 3270   NaN                  NaN                            NaN
# 3271   NaN                  NaN                            NaN
#
#      block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0                 NaN             NaN                NaN                  NaN
# ...

# %%
df = df[df['type'] == 'Carry']

# %%
df
# Out:
#      50_50 ball_receipt_outcome ball_recovery_recovery_failure  \
# 1709   NaN                  NaN                            NaN
# 1710   NaN                  NaN                            NaN
# 1711   NaN                  NaN                            NaN
# 1712   NaN                  NaN                            NaN
# 1713   NaN                  NaN                            NaN
# ...    ...                  ...                            ...
# 2353   NaN                  NaN                            NaN
# 2354   NaN                  NaN                            NaN
# 2355   NaN                  NaN                            NaN
# 2356   NaN                  NaN                            NaN
# 2357   NaN                  NaN                            NaN
#
#      block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 1709              NaN             NaN       [51.8, 36.6]                  NaN
# ...

# %%
df.columns
# Out:
# Index(['carry_end_location', 'x', 'y'], dtype='object')

# %%
print(df.player.value_counts())
# Out:
# player
# Kathrin Julia Hendrich    83
# Marina Hegering           69
# Chantal Hagel             68
# Svenja Huth               43
# Lena Oberdorf             43
# Klara Bühl                36
# So-Yun Ji                 33
# Jule Brand                32
# Sara Däbritz              26
# Alexandra Popp            21
# Yu-Ri Choe                20
# Sel-Gi Jang               19
# Merle Frohms              19
# Sydney Lohmann            19
# Ga-Ram Chun               15
# Casey Yu-Jin Phair        14
# Hyo-Joo Choo              14
# Young-Ju Lee              13
# Seo-Yeon Shim             13
# Lea Schüller              13
# So-Hyun Cho               11
# Lena Lattwein              8
# Jung-Mi Kim                7
# Hye-Ri Kim                 5
# Nicole Anyomi              3
# Mi-Ra Moon                 2
# Name: count, dtype: int64

# %%
df = df[(df['player'] == 'So-Hyun Cho')]

# %%
df = df[['x', 'y', 'carry_end_location']]

# %%
df.head()
# Out:
#          x     y carry_end_location
# 1729  46.5  28.9       [46.5, 28.9]
# 1741  84.9  71.9       [84.9, 71.9]
# 1781  40.5  56.8       [40.5, 56.8]
# 1908  22.2  39.9       [22.2, 39.9]
# 1967  64.3  75.8       [64.3, 75.8]

# %%
df[['end_x', 'end_y']] = df['carry_end_location'].apply(pd.Series)
# Out:
# C:\Users\fredd\AppData\Local\Temp\ipykernel_10988\2002353364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['end_x', 'end_y']] = df['carry_end_location'].apply(pd.Series)
# C:\Users\fredd\AppData\Local\Temp\ipykernel_10988\2002353364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['end_x', 'end_y']] = df['carry_end_location'].apply(pd.Series)

# %%
df.head()
# Out:
#          x     y carry_end_location  end_x  end_y
# 1729  46.5  28.9       [46.5, 28.9]   46.5   28.9
# 1741  84.9  71.9       [84.9, 71.9]   84.9   71.9
# 1781  40.5  56.8       [40.5, 56.8]   40.5   56.8
# 1908  22.2  39.9       [22.2, 39.9]   22.2   39.9
# 1967  64.3  75.8       [64.3, 75.8]   64.3   75.8

# %%
#calculate carry distances

# %%
from mplsoccer import Pitch

pitch = Pitch(pitch_type='opta')
fig, ax = pitch.draw()

#plot the passes by looping through the dataframe
# for x in df.to_dict(orient='records'):
#     pitch.arrows(x['x'], x['y'],
#         x['end_x'], x['end_y'], color = "#e5021c", ax=ax, width=3)
for x in df.to_dict(orient='records'):
    pitch.lines(x['x'], x['y'], x['end_x'], x['end_y'],
                ax=ax, comet=True, color='#e5021c', lw=2, alpha = 0.7)

# pitch.scatter(df['end_x'], df['end_y'], edgecolors='#e5021c', c='#e5021c',
#           s = 20, zorder=5, ax=ax, marker = 'o', alpha = 0.9,linewidths=5)
