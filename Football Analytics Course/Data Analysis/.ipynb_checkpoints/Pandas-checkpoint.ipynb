# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/fredd/Data Visualization/football-analytics/Football Analytics Course/Data Analysis/big5.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0         NaN                 Rk             Player             Nation
# 1         0.0                  1   Brenden Aaronson             us USA
# 2         1.0                  2    Paxten Aaronson             us USA
# 3         2.0                  3     James Abankwah             ie IRL
# 4         3.0                  4      George Abbott            eng ENG
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
# 0                Pos              Squad                Comp
# 1              MF,FW       Leeds United  eng Premier League
# 2              MF,DF     Eint Frankfurt       de Bundesliga
# 3                 DF            Udinese          it Serie A
# 4                 MF          Tottenham  eng Premier League
#
#   Unnamed: 6_level_0 Unnamed: 7_level_0 Playing Time  ... Per 90 Minutes.1  \
# 0                Age               Born           MP  ...              Ast
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 3000      2999.0               2885    Martin Ødegaard             no NOR
# 3001      3000.0               2886        Milan Đurić             ba BIH
# 3002      3001.0               2887      Filip Đuričić             rs SRB
# 3003      3002.0               2888             Blanco                NaN
# 3004      3003.0               2889     Hugo Guillamón                NaN
#
#      Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
# 3000                 MF            Arsenal  eng Premier League
# 3001                 FW      Hellas Verona          it Serie A
# 3002              MF,FW          Sampdoria          it Serie A
# 3003                 MF              Cádiz          es La Liga
# 3004              DF,MF           Valencia          es La Liga
#
#      Unnamed: 6_level_0 Unnamed: 7_level_0 Playing Time  ... Per 90 Minutes.1  \
# ...

# %%
#view no. of rows and columns
df.shape
# Out:
# (3005, 39)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_level_0', 'Unnamed: 1_level_0',
#        'Unnamed: 2_level_0', 'Unnamed: 3_level_0', 'Unnamed: 4_level_0',
#        'Unnamed: 5_level_0', 'Unnamed: 6_level_0', 'Unnamed: 7_level_0',
#        'Playing Time', 'Playing Time.1', 'Playing Time.2', 'Playing Time.3',
#        'Performance', 'Performance.1', 'Performance.2', 'Performance.3',
#        'Performance.4', 'Performance.5', 'Performance.6', 'Performance.7',
#        'Expected', 'Expected.1', 'Expected.2', 'Expected.3', 'Progression',
#        'Progression.1', 'Progression.2', 'Per 90 Minutes', 'Per 90 Minutes.1',
#        'Per 90 Minutes.2', 'Per 90 Minutes.3', 'Per 90 Minutes.4',
#        'Per 90 Minutes.5', 'Per 90 Minutes.6', 'Per 90 Minutes.7',
#        'Per 90 Minutes.8', 'Per 90 Minutes.9', 'Unnamed: 37_level_0'],
#       dtype='object')

# %%
#see datatypes of rows and columns
df.dtypes
# Out:
# Unnamed: 0             float64
# Unnamed: 0_level_0      object
# Unnamed: 1_level_0      object
# Unnamed: 2_level_0      object
# Unnamed: 3_level_0      object
# Unnamed: 4_level_0      object
# Unnamed: 5_level_0      object
# Unnamed: 6_level_0      object
# Unnamed: 7_level_0      object
# Playing Time            object
# Playing Time.1          object
# Playing Time.2          object
# Playing Time.3          object
# Performance             object
# Performance.1           object
# Performance.2           object
# Performance.3           object
# Performance.4           object
# Performance.5           object
# Performance.6           object
# Performance.7           object
# Expected                object
# Expected.1              object
# Expected.2              object
# Expected.3              object
# Progression             object
# Progression.1           object
# Progression.2           object
# Per 90 Minutes          object
# Per 90 Minutes.1        object
# ...

# %%
#view numerical info
df.describe()
# Out:
#        Unnamed: 0
# count  3004.00000
# mean   1501.50000
# std     867.32443
# min       0.00000
# 25%     750.75000
# 50%    1501.50000
# 75%    2252.25000
# max    3003.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3005 entries, 0 to 3004
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           3004 non-null   float64
#  1   Unnamed: 0_level_0   3005 non-null   object
#  2   Unnamed: 1_level_0   3005 non-null   object
#  3   Unnamed: 2_level_0   3003 non-null   object
#  4   Unnamed: 3_level_0   3005 non-null   object
#  5   Unnamed: 4_level_0   3005 non-null   object
#  6   Unnamed: 5_level_0   3005 non-null   object
#  7   Unnamed: 6_level_0   3005 non-null   object
#  8   Unnamed: 7_level_0   3005 non-null   object
#  9   Playing Time         3005 non-null   object
#  10  Playing Time.1       3005 non-null   object
#  11  Playing Time.2       3005 non-null   object
#  12  Playing Time.3       3005 non-null   object
#  13  Performance          3005 non-null   object
#  14  Performance.1        3005 non-null   object
# ...

# %%
df.isnull() #returns true or false for every datapoint
# Out:
#       Unnamed: 0  Unnamed: 0_level_0  Unnamed: 1_level_0  Unnamed: 2_level_0  \
# 0           True               False               False               False
# 1          False               False               False               False
# 2          False               False               False               False
# 3          False               False               False               False
# 4          False               False               False               False
# ...          ...                 ...                 ...                 ...
# 3000       False               False               False               False
# 3001       False               False               False               False
# 3002       False               False               False               False
# 3003       False               False               False                True
# 3004       False               False               False                True
#
# ...

# %%
df.isnull().sum() #returns the number of null values in each column
# Out:
# Unnamed: 0             1
# Unnamed: 0_level_0     0
# Unnamed: 1_level_0     0
# Unnamed: 2_level_0     2
# Unnamed: 3_level_0     0
# Unnamed: 4_level_0     0
# Unnamed: 5_level_0     0
# Unnamed: 6_level_0     0
# Unnamed: 7_level_0     0
# Playing Time           0
# Playing Time.1         0
# Playing Time.2         0
# Playing Time.3         0
# Performance            0
# Performance.1          0
# Performance.2          0
# Performance.3          0
# Performance.4          0
# Performance.5          0
# Performance.6          0
# Performance.7          0
# Expected               3
# Expected.1             3
# Expected.2             3
# Expected.3             3
# Progression            3
# Progression.1          3
# Progression.2          3
# Per 90 Minutes         0
# Per 90 Minutes.1       0
# Per 90 Minutes.2       0
# Per 90 Minutes.3       0
# Per 90 Minutes.4       0
# Per 90 Minutes.5       3
# Per 90 Minutes.6       3
# Per 90 Minutes.7       3
# Per 90 Minutes.8       3
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
# 0         NaN                 Rk             Player             Nation
# 1         0.0                  1   Brenden Aaronson             us USA
# 2         1.0                  2    Paxten Aaronson             us USA
# 3         2.0                  3     James Abankwah             ie IRL
# 4         3.0                  4      George Abbott            eng ENG
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0  Unnamed: 5_level_0  \
# 0                Pos              Squad                Comp
# 1              MF,FW       Leeds United  eng Premier League
# 2              MF,DF     Eint Frankfurt       de Bundesliga
# 3                 DF            Udinese          it Serie A
# 4                 MF          Tottenham  eng Premier League
#
#   Unnamed: 6_level_0 Unnamed: 7_level_0 Playing Time  ... Per 90 Minutes.1  \
# 0                Age               Born           MP  ...              Ast
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1) #axis=1 is for columns and axis=0 is for rows

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Rk            Player Unnamed: 2_level_0 Nation  \
# 1                     1  Brenden Aaronson                    us USA
# 2                     2   Paxten Aaronson                    us USA
# 3                     3    James Abankwah                    ie IRL
# 4                     4     George Abbott                   eng ENG
# 5                     5  Yunis Abdelhamid                    ma MAR
#
#   Unnamed: 3_level_0 Pos Unnamed: 4_level_0 Squad Unnamed: 5_level_0 Comp  \
# 1                  MF,FW             Leeds United      eng Premier League
# 2                  MF,DF           Eint Frankfurt           de Bundesliga
# 3                     DF                  Udinese              it Serie A
# 4                     MF                Tottenham      eng Premier League
# 5                     DF                    Reims              fr Ligue 1
#
#   Unnamed: 6_level_0 Age Unnamed: 7_level_0 Born Playing Time MP  \
# ...

# %%
df.columns = df.columns + ' ' + df.iloc[0] #move rows at index 0 up

# %%
df = df.drop(0) #drops row 0

# %%
df = df.rename(columns={'Unnamed: 1_level_0 Player' : 'Player'}) #rename column

# %%
df = df.rename(columns=lambda x: x.split(' ')[-1] if 'Unnamed' in x else x)

# %%
df.head()
# Out:
#   Rk            Player   Nation    Pos           Squad                Comp  \
# 0  1  Brenden Aaronson   us USA  MF,FW    Leeds United  eng Premier League
# 1  2   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt       de Bundesliga
# 2  3    James Abankwah   ie IRL     DF         Udinese          it Serie A
# 3  4     George Abbott  eng ENG     MF       Tottenham  eng Premier League
# 4  5  Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
#
#   Age  Born Playing Time MP Playing Time.1 Starts  ... Per 90 Minutes.1 Ast  \
# 0  21  2000              36                    28  ...                 0.11
# 1  18  2003               7                     0  ...                 0.00
# 2  18  2004               2                     1  ...                 0.00
# 3  16  2005               1                     0  ...                 0.00
# 4  34  1987              37                    37  ...                 0.05
#
# ...

# %%
#reset the index
df.reset_index(drop=True)
# Out:
#         Rk            Player   Nation    Pos           Squad  \
# 0        1  Brenden Aaronson   us USA  MF,FW    Leeds United
# 1        2   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt
# 2        3    James Abankwah   ie IRL     DF         Udinese
# 3        4     George Abbott  eng ENG     MF       Tottenham
# 4        5  Yunis Abdelhamid   ma MAR     DF           Reims
# ...    ...               ...      ...    ...             ...
# 2999  2885   Martin Ødegaard   no NOR     MF         Arsenal
# 3000  2886       Milan Đurić   ba BIH     FW   Hellas Verona
# 3001  2887     Filip Đuričić   rs SRB  MF,FW       Sampdoria
# 3002  2888            Blanco      NaN     MF           Cádiz
# 3003  2889    Hugo Guillamón      NaN  DF,MF        Valencia
#
#                     Comp Age  Born Playing Time MP Playing Time.1 Starts  ...  \
# 0     eng Premier League  21  2000              36                    28  ...
# ...

# %%
df.loc[0:5, 'Player':'Comp'] #get specific parts of table
# Out:
#              Player   Nation    Pos           Squad                Comp
# 0  Brenden Aaronson   us USA  MF,FW    Leeds United  eng Premier League
# 1   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt       de Bundesliga
# 2    James Abankwah   ie IRL     DF         Udinese          it Serie A
# 3     George Abbott  eng ENG     MF       Tottenham  eng Premier League
# 4  Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
# 5     Himad Abdelli   dz ALG  MF,FW          Angers          fr Ligue 1

# %%
df.iloc[0:5, 0:5]
# Out:
#   Rk            Player   Nation    Pos           Squad
# 0  1  Brenden Aaronson   us USA  MF,FW    Leeds United
# 1  2   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt
# 2  3    James Abankwah   ie IRL     DF         Udinese
# 3  4     George Abbott  eng ENG     MF       Tottenham
# 4  5  Yunis Abdelhamid   ma MAR     DF           Reims

# %%
#filter a dataframe
prem = df[df['Comp'] == 'eng Premier League']
prem.head()
# Out:
#     Rk            Player   Nation    Pos         Squad                Comp  \
# 0    1  Brenden Aaronson   us USA  MF,FW  Leeds United  eng Premier League
# 3    4     George Abbott  eng ENG     MF     Tottenham  eng Premier League
# 19  20         Che Adams  sct SCO     FW   Southampton  eng Premier League
# 20  21       Tyler Adams   us USA     MF  Leeds United  eng Premier League
# 22  23  Tosin Adarabioyo  eng ENG     DF        Fulham  eng Premier League
#
#    Age  Born Playing Time MP Playing Time.1 Starts  ... Per 90 Minutes.1 Ast  \
# 0   21  2000              36                    28  ...                 0.11
# 3   16  2005               1                     0  ...                 0.00
# 19  26  1996              28                    23  ...                 0.14
# 20  23  1999              24                    24  ...                 0.00
# 22  24  1997              25                    23  ...                 0.00
#
# ...

# %%
prem = df[(df['Comp'] == 'eng Premier League') & (df['Playing Time MP'] > 20)]

print(prem.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 prem = df[(df['Comp'] == 'eng Premier League') & (df['Playing Time MP'] > 20)]
#       3 print(prem.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
