# %%
import requests


params = {
    'matchId': '4193903', #can switch matchId for different matches
}

response = requests.get('https://www.fotmob.com/api/matchDetails', params=params)

# %%
data = response.json()

# %%
shotmap = data['content']['shotmap']['shots']

# %%
shotmap[0]
# Out:
# {'id': 2689629089,
#  'eventType': 'Miss',
#  'teamId': 10204,
#  'playerId': 303346,
#  'playerName': 'Adam Webster',
#  'x': 101.3017241382,
#  'y': 26.942142857,
#  'min': 5,
#  'minAdded': None,
#  'isBlocked': False,
#  'isOnTarget': False,
#  'blockedX': None,
#  'blockedY': None,
#  'goalCrossedY': 31.78875,
#  'goalCrossedZ': 4.5846896616,
#  'expectedGoals': 0.06405066698789597,
#  'expectedGoalsOnTarget': None,
#  'shotType': 'Header',
#  'situation': 'FromCorner',
#  'period': 'FirstHalf',
#  'isOwnGoal': False,
#  'onGoalShot': {'x': 1.3266450399269785,
#   'y': 0.6772486772486772,
#   'zoomRatio': 0.5583802152284811},
#  'isSavedOffLine': False,
#  'isFromInsideBox': True,
#  'firstName': 'Adam',
#  'lastName': 'Webster',
#  'fullName': 'Adam Webster',
#  'teamColor': '#0850A0'}

# %%
import pandas as pd

df = pd.DataFrame(shotmap)

# %%
df.head()
# Out:
#            id     eventType  teamId  playerId       playerName           x  \
# 0  2689629089          Miss   10204    303346     Adam Webster  101.301724
# 1  2689638369  AttemptSaved   10260    422685  Bruno Fernandes   79.894660
# 2  2689640593  AttemptSaved   10204   1272440   Valentin Barco   96.122807
# 3  2689648763  AttemptSaved   10204    891855      Jakub Moder   95.736842
# 4  2689653757  AttemptSaved   10204   1021382       Joao Pedro   91.600000
#
#            y  min  minAdded  isBlocked  ...     period  isOwnGoal  \
# 0  26.942143    5       NaN      False  ...  FirstHalf      False
# 1  21.266752   11       NaN      False  ...  FirstHalf      False
# 2  44.911592   12       NaN      False  ...  FirstHalf      False
# 3  27.782619   18       NaN      False  ...  FirstHalf      False
# 4  30.340000   21       NaN       True  ...  FirstHalf      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': 1.3266450399269785, 'y': 0.6772486772486...           False
# 1  {'x': 0.33432539682539697, 'y': 0.332943468148...           False
# 2  {'x': 1.2017195767195774, 'y': 0.1070175433333...           False
# 3  {'x': 0.09226190476190332, 'y': 0.193650792698...           False
# 4  {'x': 1.121031746031747, 'y': 0.32275132116402...           False
#
#    isFromInsideBox  firstName   lastName         fullName teamColor shortName
# 0             True       Adam    Webster     Adam Webster   #0850A0       NaN
# 1            False      Bruno  Fernandes  Bruno Fernandes   #C70101       NaN
# 2             True   Valentin      Barco   Valentin Barco   #0850A0       NaN
# 3             True      Jakub      Moder      Jakub Moder   #0850A0       NaN
# 4             True       Joao      Pedro       Joao Pedro   #0850A0       NaN
#
# [5 rows x 29 columns]

# %%
df.to_csv('file path')
