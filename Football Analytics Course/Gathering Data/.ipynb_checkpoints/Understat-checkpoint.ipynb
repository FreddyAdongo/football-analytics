# %%
import re
import json
import requests

from bs4 import BeautifulSoup

import pandas as pd

# %%
url = 'https://understat.com/match/22267'

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')
ugly_soup = str(soup)

# %%
shots_data = re.search("var shotsData .*= JSON.parse\('(.*)'\)", 
                       ugly_soup).group(1)

# %%
shots_data[:100]
# Out:
# '\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22582128\\x22,\\x22minute\\x22\\x3A\\x224\\x22,\\x22result\\x22\\x3A'

# %%
data = shots_data.encode('utf8').decode('unicode_escape')

# %%
data[:100]
# Out:
# '{"h":[{"id":"582128","minute":"4","result":"MissedShots","X":"0.960999984741211","Y":"0.402999992370'

# %%
data = json.loads(data)

# %%
data
# Out:
# {'h': [{'id': '582128',
#    'minute': '4',
#    'result': 'MissedShots',
#    'X': '0.960999984741211',
#    'Y': '0.40299999237060546',
#    'xG': '0.018925296142697334',
#    'player': 'Adam Webster',
#    'h_a': 'h',
#    'player_id': '7699',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Pascal Groß',
#    'lastAction': 'Aerial'},
#   {'id': '582130',
#    'minute': '11',
#    'result': 'SavedShot',
#    'X': '0.9069999694824219',
#    'Y': '0.6569999694824219',
#    'xG': '0.27490857243537903',
#    'player': 'Valentín Barco',
#    'h_a': 'h',
#    'player_id': '12498',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Carlos Baleba',
#    'lastAction': 'Pass'},
#   {'id': '582131',
#    'minute': '17',
#    'result': 'SavedShot',
#    'X': '0.9030000305175782',
#    'Y': '0.4129999923706055',
#    'xG': '0.0625562071800232',
#    'player': 'Jakub Moder',
#    'h_a': 'h',
#    'player_id': '9284',
#    'situation': 'SetPiece',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Pascal Groß',
#    'lastAction': 'Cross'},
#   {'id': '582132',
#    'minute': '20',
#    'result': 'BlockedShot',
#    'X': '0.860999984741211',
#    'Y': '0.4520000076293945',
#    'xG': '0.10473421216011047',
#    'player': 'João Pedro',
#    'h_a': 'h',
#    'player_id': '8272',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Danny Welbeck',
#    'lastAction': 'Pass'},
#   {'id': '582133',
#    'minute': '22',
#    'result': 'MissedShots',
#    'X': '0.904000015258789',
#    'Y': '0.5579999923706055',
#    'xG': '0.03518944978713989',
#    'player': 'Adam Webster',
#    'h_a': 'h',
#    'player_id': '7699',
#    'situation': 'SetPiece',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '582135',
#    'minute': '27',
#    'result': 'BlockedShot',
#    'X': '0.799000015258789',
#    'Y': '0.37',
#    'xG': '0.026056284084916115',
#    'player': 'Carlos Baleba',
#    'h_a': 'h',
#    'player_id': '10527',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Adam Lallana',
#    'lastAction': 'Pass'},
#   {'id': '582136',
#    'minute': '28',
#    'result': 'BlockedShot',
#    'X': '0.9130000305175782',
#    'Y': '0.43099998474121093',
#    'xG': '0.05778523162007332',
#    'player': 'Adam Webster',
#    'h_a': 'h',
#    'player_id': '7699',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Valentín Barco',
#    'lastAction': 'Cross'},
#   {'id': '582137',
#    'minute': '31',
#    'result': 'MissedShots',
#    'X': '0.93',
#    'Y': '0.39799999237060546',
#    'xG': '0.3987084627151489',
#    'player': 'João Pedro',
#    'h_a': 'h',
#    'player_id': '8272',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Dispossessed'},
#   {'id': '582138',
#    'minute': '34',
#    'result': 'BlockedShot',
#    'X': '0.7709999847412109',
#    'Y': '0.4129999923706055',
#    'xG': '0.024687567725777626',
#    'player': 'Adam Lallana',
#    'h_a': 'h',
#    'player_id': '486',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Danny Welbeck',
#    'lastAction': 'Pass'},
#   {'id': '582139',
#    'minute': '36',
#    'result': 'BlockedShot',
#    'X': '0.9069999694824219',
#    'Y': '0.6480000305175782',
#    'xG': '0.09209132194519043',
#    'player': 'Adam Lallana',
#    'h_a': 'h',
#    'player_id': '486',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'João Pedro',
#    'lastAction': 'Pass'},
#   {'id': '582141',
#    'minute': '47',
#    'result': 'BlockedShot',
#    'X': '0.8159999847412109',
#    'Y': '0.610999984741211',
#    'xG': '0.03523308411240578',
#    'player': 'Pascal Groß',
#    'h_a': 'h',
#    'player_id': '239',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'João Pedro',
#    'lastAction': 'Pass'},
#   {'id': '582142',
#    'minute': '49',
#    'result': 'BlockedShot',
#    'X': '0.9319999694824219',
#    'Y': '0.505',
#    'xG': '0.5778364539146423',
#    'player': 'João Pedro',
#    'h_a': 'h',
#    'player_id': '8272',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Jakub Moder',
#    'lastAction': 'Pass'},
#   {'id': '582143',
#    'minute': '49',
#    'result': 'BlockedShot',
#    'X': '0.9069999694824219',
#    'Y': '0.534000015258789',
#    'xG': '0.13714651763439178',
#    'player': 'Adam Lallana',
#    'h_a': 'h',
#    'player_id': '486',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Pascal Groß',
#    'lastAction': 'Pass'},
#   {'id': '582144',
#    'minute': '50',
#    'result': 'BlockedShot',
#    'X': '0.9080000305175782',
#    'Y': '0.4779999923706055',
#    'xG': '0.03320244699716568',
#    'player': 'João Pedro',
#    'h_a': 'h',
#    'player_id': '8272',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Simon Adingra',
#    'lastAction': 'Aerial'},
#   {'id': '582147',
#    'minute': '62',
#    'result': 'MissedShots',
#    'X': '0.759000015258789',
#    'Y': '0.47',
#    'xG': '0.014393741264939308',
#    'player': 'Jakub Moder',
#    'h_a': 'h',
#    'player_id': '9284',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '582153',
#    'minute': '84',
#    'result': 'MissedShots',
#    'X': '0.9109999847412109',
#    'Y': '0.3629999923706055',
#    'xG': '0.014872423373162746',
#    'player': 'João Pedro',
#    'h_a': 'h',
#    'player_id': '8272',
#    'situation': 'FromCorner',
#    'season': '2023',
#    'shotType': 'Head',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Pascal Groß',
#    'lastAction': 'Cross'},
#   {'id': '582155',
#    'minute': '92',
#    'result': 'BlockedShot',
#    'X': '0.8809999847412109',
#    'Y': '0.36900001525878906',
#    'xG': '0.06337729096412659',
#    'player': 'Anssumane Fati',
#    'h_a': 'h',
#    'player_id': '7967',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Tackle'}],
#  'a': [{'id': '582129',
#    'minute': '10',
#    'result': 'SavedShot',
#    'X': '0.7419999694824219',
#    'Y': '0.27899999618530275',
#    'xG': '0.013111126609146595',
#    'player': 'Bruno Fernandes',
#    'h_a': 'a',
#    'player_id': '1228',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Kobbie Mainoo',
#    'lastAction': 'BallRecovery'},
#   {'id': '582134',
#    'minute': '25',
#    'result': 'MissedShots',
#    'X': '0.895',
#    'Y': '0.335',
#    'xG': '0.09822201728820801',
#    'player': 'Scott McTominay',
#    'h_a': 'a',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Bruno Fernandes',
#    'lastAction': 'Pass'},
#   {'id': '582140',
#    'minute': '41',
#    'result': 'SavedShot',
#    'X': '0.9630000305175781',
#    'Y': '0.705',
#    'xG': '0.05171780288219452',
#    'player': 'Alejandro Garnacho',
#    'h_a': 'a',
#    'player_id': '10552',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Diogo Dalot',
#    'lastAction': 'TakeOn'},
#   {'id': '582145',
#    'minute': '51',
#    'result': 'BlockedShot',
#    'X': '0.8530000305175781',
#    'Y': '0.6869999694824219',
#    'xG': '0.03835659474134445',
#    'player': 'Alejandro Garnacho',
#    'h_a': 'a',
#    'player_id': '10552',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Diogo Dalot',
#    'lastAction': 'Chipped'},
#   {'id': '582146',
#    'minute': '54',
#    'result': 'BlockedShot',
#    'X': '0.8880000305175781',
#    'Y': '0.54',
#    'xG': '0.1000174731016159',
#    'player': 'Scott McTominay',
#    'h_a': 'a',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Kobbie Mainoo',
#    'lastAction': 'BallTouch'},
#   {'id': '582148',
#    'minute': '62',
#    'result': 'BlockedShot',
#    'X': '0.8859999847412109',
#    'Y': '0.43599998474121093',
#    'xG': '0.11147138476371765',
#    'player': 'Scott McTominay',
#    'h_a': 'a',
#    'player_id': '5560',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Amad Diallo Traore',
#    'lastAction': 'Pass'},
#   {'id': '582149',
#    'minute': '63',
#    'result': 'MissedShots',
#    'X': '0.79',
#    'Y': '0.35',
#    'xG': '0.022723201662302017',
#    'player': 'Amad Diallo Traore',
#    'h_a': 'a',
#    'player_id': '8127',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Rasmus Højlund',
#    'lastAction': 'Pass'},
#   {'id': '582150',
#    'minute': '67',
#    'result': 'BlockedShot',
#    'X': '0.8440000152587891',
#    'Y': '0.375',
#    'xG': '0.06360965967178345',
#    'player': 'Alejandro Garnacho',
#    'h_a': 'a',
#    'player_id': '10552',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Amad Diallo Traore',
#    'lastAction': 'Pass'},
#   {'id': '582151',
#    'minute': '72',
#    'result': 'Goal',
#    'X': '0.8730000305175781',
#    'Y': '0.435',
#    'xG': '0.3615990877151489',
#    'player': 'Diogo Dalot',
#    'h_a': 'a',
#    'player_id': '7281',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '582152',
#    'minute': '82',
#    'result': 'BlockedShot',
#    'X': '0.79',
#    'Y': '0.4229999923706055',
#    'xG': '0.04323812574148178',
#    'player': 'Alejandro Garnacho',
#    'h_a': 'a',
#    'player_id': '10552',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'LeftFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Casemiro',
#    'lastAction': 'Chipped'},
#   {'id': '582154',
#    'minute': '87',
#    'result': 'Goal',
#    'X': '0.894000015258789',
#    'Y': '0.3890000152587891',
#    'xG': '0.09996958076953888',
#    'player': 'Rasmus Højlund',
#    'h_a': 'a',
#    'player_id': '11055',
#    'situation': 'OpenPlay',
#    'season': '2023',
#    'shotType': 'RightFoot',
#    'match_id': '22267',
#    'h_team': 'Brighton',
#    'a_team': 'Manchester United',
#    'h_goals': '0',
#    'a_goals': '2',
#    'date': '2024-05-19 15:00:00',
#    'player_assisted': 'Christian Eriksen',
#    'lastAction': 'TakeOn'}]}

# %%
home_df = pd.DataFrame(data['h'])
away_df = pd.DataFrame(data['a'])

# %%
home_df
# Out:
#         id minute       result                   X                    Y  \
# 0   582128      4  MissedShots   0.960999984741211  0.40299999237060546
# 1   582130     11    SavedShot  0.9069999694824219   0.6569999694824219
# 2   582131     17    SavedShot  0.9030000305175782   0.4129999923706055
# 3   582132     20  BlockedShot   0.860999984741211   0.4520000076293945
# 4   582133     22  MissedShots   0.904000015258789   0.5579999923706055
# 5   582135     27  BlockedShot   0.799000015258789                 0.37
# 6   582136     28  BlockedShot  0.9130000305175782  0.43099998474121093
# 7   582137     31  MissedShots                0.93  0.39799999237060546
# 8   582138     34  BlockedShot  0.7709999847412109   0.4129999923706055
# 9   582139     36  BlockedShot  0.9069999694824219   0.6480000305175782
# 10  582141     47  BlockedShot  0.8159999847412109    0.610999984741211
# 11  582142     49  BlockedShot  0.9319999694824219                0.505
# 12  582143     49  BlockedShot  0.9069999694824219    0.534000015258789
# 13  582144     50  BlockedShot  0.9080000305175782   0.4779999923706055
# 14  582147     62  MissedShots   0.759000015258789                 0.47
# 15  582153     84  MissedShots  0.9109999847412109   0.3629999923706055
# 16  582155     92  BlockedShot  0.8809999847412109  0.36900001525878906
#
#                       xG          player h_a player_id   situation season  \
# 0   0.018925296142697334    Adam Webster   h      7699  FromCorner   2023
# 1    0.27490857243537903  Valentín Barco   h     12498    OpenPlay   2023
# 2     0.0625562071800232     Jakub Moder   h      9284    SetPiece   2023
# 3    0.10473421216011047      João Pedro   h      8272    OpenPlay   2023
# 4    0.03518944978713989    Adam Webster   h      7699    SetPiece   2023
# 5   0.026056284084916115   Carlos Baleba   h     10527    OpenPlay   2023
# 6    0.05778523162007332    Adam Webster   h      7699  FromCorner   2023
# 7     0.3987084627151489      João Pedro   h      8272    OpenPlay   2023
# 8   0.024687567725777626    Adam Lallana   h       486    OpenPlay   2023
# 9    0.09209132194519043    Adam Lallana   h       486    OpenPlay   2023
# 10   0.03523308411240578     Pascal Groß   h       239    OpenPlay   2023
# 11    0.5778364539146423      João Pedro   h      8272    OpenPlay   2023
# 12   0.13714651763439178    Adam Lallana   h       486    OpenPlay   2023
# 13   0.03320244699716568      João Pedro   h      8272  FromCorner   2023
# 14  0.014393741264939308     Jakub Moder   h      9284  FromCorner   2023
# 15  0.014872423373162746      João Pedro   h      8272  FromCorner   2023
# 16   0.06337729096412659  Anssumane Fati   h      7967    OpenPlay   2023
#
#      shotType match_id    h_team             a_team h_goals a_goals  \
# 0        Head    22267  Brighton  Manchester United       0       2
# 1    LeftFoot    22267  Brighton  Manchester United       0       2
# 2   RightFoot    22267  Brighton  Manchester United       0       2
# 3   RightFoot    22267  Brighton  Manchester United       0       2
# 4        Head    22267  Brighton  Manchester United       0       2
# 5    LeftFoot    22267  Brighton  Manchester United       0       2
# 6        Head    22267  Brighton  Manchester United       0       2
# 7   RightFoot    22267  Brighton  Manchester United       0       2
# 8    LeftFoot    22267  Brighton  Manchester United       0       2
# 9    LeftFoot    22267  Brighton  Manchester United       0       2
# 10  RightFoot    22267  Brighton  Manchester United       0       2
# 11  RightFoot    22267  Brighton  Manchester United       0       2
# 12   LeftFoot    22267  Brighton  Manchester United       0       2
# 13       Head    22267  Brighton  Manchester United       0       2
# 14  RightFoot    22267  Brighton  Manchester United       0       2
# 15       Head    22267  Brighton  Manchester United       0       2
# 16  RightFoot    22267  Brighton  Manchester United       0       2
#
#                    date player_assisted    lastAction
# 0   2024-05-19 15:00:00     Pascal Groß        Aerial
# 1   2024-05-19 15:00:00   Carlos Baleba          Pass
# 2   2024-05-19 15:00:00     Pascal Groß         Cross
# 3   2024-05-19 15:00:00   Danny Welbeck          Pass
# 4   2024-05-19 15:00:00            None          None
# 5   2024-05-19 15:00:00    Adam Lallana          Pass
# 6   2024-05-19 15:00:00  Valentín Barco         Cross
# 7   2024-05-19 15:00:00            None  Dispossessed
# 8   2024-05-19 15:00:00   Danny Welbeck          Pass
# 9   2024-05-19 15:00:00      João Pedro          Pass
# 10  2024-05-19 15:00:00      João Pedro          Pass
# 11  2024-05-19 15:00:00     Jakub Moder          Pass
# 12  2024-05-19 15:00:00     Pascal Groß          Pass
# 13  2024-05-19 15:00:00   Simon Adingra        Aerial
# 14  2024-05-19 15:00:00            None        Aerial
# 15  2024-05-19 15:00:00     Pascal Groß         Cross
# 16  2024-05-19 15:00:00            None        Tackle
