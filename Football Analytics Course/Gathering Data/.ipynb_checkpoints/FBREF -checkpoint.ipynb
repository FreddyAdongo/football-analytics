# %%
import pandas as pd

# %%
df = pd.read_html('https://fbref.com/en/comps/182/NWSL-Stats', 
                  attrs={"id" : "results20241821_overall"})[0]

# %%
df.head()
# Out:
#    Rk      Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# 0   1      Pride  10  7  3  0  18   9   9   24     2.4  17.3  10.0   7.4
# 1   2    Current  10  6  4  0  25  15  10   22     2.2  21.1   9.8  11.3
# 2   3     Spirit  10  7  0  3  22  14   8   21     2.1  17.5  11.3   6.2
# 3   4     Thorns  10  6  1  3  23  14   9   19     1.9  16.3  13.0   3.3
# 4   5  Red Stars  10  5  1  4  15  14   1   16     1.6  13.4  13.8  -0.4
#
#    xGD/90     Last 5  Attendance                    Top Team Scorer  \
# 0    0.74  W W W W W        6473                   Barbra Banda - 6
# 1    1.13  W D D W D        6900                 Temwa Chawinga - 5
# 2    0.62  L W L W W        7996  Ouleymata Sarr, Croix Bethune - 4
# 3    0.33  W W W W W       18279                   Sophia Smith - 8
# 4   -0.04  L L W W L        2763               Allyson Schlegel - 4
#
#          Goalkeeper  Notes
# 0    Anna Moorhouse    NaN
# 1   Adrianna Franch    NaN
# 2  Aubrey Kingsbury    NaN
# ...

# %%
df = df.dropna(subset=['Rk'])

# %%
df.head()
# Out:
#    Rk      Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  \
# 0   1      Pride  10  7  3  0  18   9   9   24     2.4  17.3  10.0   7.4
# 1   2    Current  10  6  4  0  25  15  10   22     2.2  21.1   9.8  11.3
# 2   3     Spirit  10  7  0  3  22  14   8   21     2.1  17.5  11.3   6.2
# 3   4     Thorns  10  6  1  3  23  14   9   19     1.9  16.3  13.0   3.3
# 4   5  Red Stars  10  5  1  4  15  14   1   16     1.6  13.4  13.8  -0.4
#
#    xGD/90     Last 5  Attendance                    Top Team Scorer  \
# 0    0.74  W W W W W        6473                   Barbra Banda - 6
# 1    1.13  W D D W D        6900                 Temwa Chawinga - 5
# 2    0.62  L W L W W        7996  Ouleymata Sarr, Croix Bethune - 4
# 3    0.33  W W W W W       18279                   Sophia Smith - 8
# 4   -0.04  L L W W L        2763               Allyson Schlegel - 4
#
#          Goalkeeper  Notes
# 0    Anna Moorhouse    NaN
# 1   Adrianna Franch    NaN
# 2  Aubrey Kingsbury    NaN
# ...

# %%
df = pd.read_html('https://fbref.com/en/squads/85c458aa/North-Carolina-Courage-Stats',
                 attrs={"id": "stats_standard_182"})[0]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0      Kaleigh Kurtz             us USA                 DF             26-254
# 1       Casey Murphy             us USA                 GK             28-025
# 2      Ryan Williams             us USA                 DF             28-087
# 3    Felicitas Rauch             de GER                 DF             28-020
# 4     Ashley Sanchez             us USA                 MF             25-065
#
#   Playing Time                     Performance       ... Per 90 Minutes        \
#             MP Starts    Min   90s         Gls  Ast  ...            Ast   G+A
# 0           10     10  900.0  10.0         1.0  0.0  ...           0.00  0.10
# 1           10     10  900.0  10.0         0.0  0.0  ...           0.00  0.00
# 2           10     10  900.0  10.0         0.0  0.0  ...           0.00  0.00
# ...

# %%
df.columns.values
# Out:
# array([('Unnamed: 0_level_0', 'Player'), ('Unnamed: 1_level_0', 'Nation'),
#        ('Unnamed: 2_level_0', 'Pos'), ('Unnamed: 3_level_0', 'Age'),
#        ('Playing Time', 'MP'), ('Playing Time', 'Starts'),
#        ('Playing Time', 'Min'), ('Playing Time', '90s'),
#        ('Performance', 'Gls'), ('Performance', 'Ast'),
#        ('Performance', 'G+A'), ('Performance', 'G-PK'),
#        ('Performance', 'PK'), ('Performance', 'PKatt'),
#        ('Performance', 'CrdY'), ('Performance', 'CrdR'),
#        ('Expected', 'xG'), ('Expected', 'npxG'), ('Expected', 'xAG'),
#        ('Expected', 'npxG+xAG'), ('Progression', 'PrgC'),
#        ('Progression', 'PrgP'), ('Progression', 'PrgR'),
#        ('Per 90 Minutes', 'Gls'), ('Per 90 Minutes', 'Ast'),
#        ('Per 90 Minutes', 'G+A'), ('Per 90 Minutes', 'G-PK'),
#        ('Per 90 Minutes', 'G+A-PK'), ('Per 90 Minutes', 'xG'),
#        ('Per 90 Minutes', 'xAG'), ('Per 90 Minutes', 'xG+xAG'),
# ...

# %%
df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %%
df.head()
# Out:
#   Unnamed: 0_level_0_Player Unnamed: 1_level_0_Nation Unnamed: 2_level_0_Pos  \
# 0             Kaleigh Kurtz                    us USA                     DF
# 1              Casey Murphy                    us USA                     GK
# 2             Ryan Williams                    us USA                     DF
# 3           Felicitas Rauch                    de GER                     DF
# 4            Ashley Sanchez                    us USA                     MF
#
#   Unnamed: 3_level_0_Age  Playing Time_MP  Playing Time_Starts  \
# 0                 26-254               10                   10
# 1                 28-025               10                   10
# 2                 28-087               10                   10
# 3                 28-020               10                   10
# 4                 25-065               10                   10
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  ...  \
# ...
