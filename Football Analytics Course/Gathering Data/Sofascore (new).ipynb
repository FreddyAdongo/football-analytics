# %%
import json
import os

url = 'https://www.sofascore.com/api/v1/event/12026318/shotmap'

# %%
result = os.popen(
    f'curl -H "Host: api.sofascore.com" -H "Accept: */*" -H "User-Agent: curl/8.1.2" https://www.sofascore.com/api/v1/event/12026318/shotmap'
).read()

# %%
shotmap = json.loads(result)

# %%
shotmap
# Out:
# {'shotmap': [{'player': {'name': 'Emeri Adames',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'emeri-adames',
#     'shortName': 'E. Adames',
#     'position': 'F',
#     'jerseyNumber': '47',
#     'userCount': 5,
#     'id': 1416840},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 20.4, 'y': 37.9, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 57.5, 'z': 73.6},
#    'id': 3263432,
#    'time': 90,
#    'addedTime': 7,
#    'timeSeconds': 5764,
#    'draw': {'start': {'x': 37.9, 'y': 20.4},
#     'end': {'x': 42.5, 'y': 0},
#     'goal': {'x': 42.5, 'y': 26.4}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 536,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Veronica Latsko',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'veronica-latsko',
#     'shortName': 'V. Latsko',
#     'position': 'M',
# ...

# %%
import pandas as pd

df = pd.DataFrame(shotmap['shotmap'])

# %%
df.head()
# Out:
#                                               player  isHome shotType  \
# 0  {'name': 'Emeri Adames', 'firstName': '', 'las...    True     miss
# 1  {'name': 'Veronica Latsko', 'firstName': '', '...    True    block
# 2  {'name': 'Jessica Fishlock', 'firstName': '', ...    True    block
# 3  {'name': 'Marta', 'slug': 'marta', 'shortName'...   False     save
# 4  {'name': 'Tziarra King', 'firstName': '', 'las...    True     miss
#
#   situation               playerCoordinates    bodyPart goalMouthLocation  \
# 0   regular  {'x': 20.4, 'y': 37.9, 'z': 0}   left-foot         high-left
# 1   regular  {'x': 13.2, 'y': 67.6, 'z': 0}   left-foot       high-centre
# 2  assisted  {'x': 23.8, 'y': 49.7, 'z': 0}  right-foot        low-centre
# 3  assisted     {'x': 8.1, 'y': 49, 'z': 0}  right-foot        low-centre
# 4  assisted   {'x': 9.3, 'y': 25.2, 'z': 0}   left-foot              high
#
#              goalMouthCoordinates       id  time  addedTime  timeSeconds  \
# ...
