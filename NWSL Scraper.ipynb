# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get(
    'https://www.nwslsoccer.com/match/6cf0f0e5de174d8b9752c6907bf96ad7/north-carolina-courage-vs-seattle-reign/stats',
    headers={
         'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }
)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
import requests

import requests

headers = {
    'authority': 'nwsl-api-prd-sdp.akamized.net',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"932bdb64a5"',
    'origin': 'https://www.nwslsoccer.com/',
    'referer': 'https://www.nwslsoccer.com/',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

response = requests.get('https://nwsl-api-prd-sdp.akamaized.net/v1/nwsl/football/seasons/nwsl::Football_Season::fe17bea0b7234cf7957c7249cb828270/match/nwsl::Football_Match::6cf0f0e5de174d8b9752c6907bf96ad7/teamstats',
                        headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
headers['if-Modified-Since'] = 'Sun, 28 Apr 2024 00:00:00 EST'

# %%
response = requests.get('https://nwsl-api-prd-sdp.akamaized.net/v1/nwsl/football/seasons/nwsl::Football_Season::fe17bea0b7234cf7957c7249cb828270/match/nwsl::Football_Match::6cf0f0e5de174d8b9752c6907bf96ad7/teamstats', headers=headers)

# %%
data = response.json()

# %%
data
# Out:
# {'stats': [{'statsId': 'possession-perc',
#    'statsLabel': 'Possession %',
#    'statsValueHome': 56,
#    'statsValueAway': 44},
#   {'statsId': 'shots',
#    'statsLabel': 'Shots',
#    'statsValueHome': 10,
#    'statsValueAway': 17},
#   {'statsId': 'blocked-shots',
#    'statsLabel': 'Blocked Shots',
#    'statsValueHome': 1,
#    'statsValueAway': 5},
#   {'statsId': 'total-passes',
#    'statsLabel': 'Total Passes',
#    'statsValueHome': 427,
#    'statsValueAway': 313},
#   {'statsId': 'passing-accuracy-perc',
#    'statsLabel': 'Passing Accuracy %',
#    'statsValueHome': 81,
#    'statsValueAway': 75},
#   {'statsId': 'corners',
#    'statsLabel': 'Corners',
#    'statsValueHome': 2,
#    'statsValueAway': 3},
#   {'statsId': 'crosses',
#    'statsLabel': 'Crosses',
#    'statsValueHome': 17,
#    'statsValueAway': 13},
#   {'statsId': 'offsides',
#    'statsLabel': 'Offsides',
#    'statsValueHome': 0,
#    'statsValueAway': 3},
#   {'statsId': 'duels-won',
# ...
