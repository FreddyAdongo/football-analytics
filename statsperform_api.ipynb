# %%
import json
import requests

# %%
from  bs4 import BeautifulSoup

# %%
response = requests.get(
    'https://www.nwslsoccer.com/match/26a0ba49f661455cb36f73b3228fb77b/north-carolina-courage-vs-bay-fc',
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'}
)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
headers = {
    'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
    'Content-Type': 'application/json; charset=UTF-8',
    'Referer': 'https://www.nwslsoccer.com',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'locale': 'en-US',
}

response = requests.get(
    'https://api.performfeeds.com/soccerdata/matchevent/1s6fchmargfcg1d0fliiw5eqej/8iyibztji1sidl05z036i0lck?_rt=c&_lcl=us&_fmt=jsonp&_clbk=W3ee513bff5eaa6b742f08942b74f64119ba59bb7e',
    params=params,
    headers=headers,
)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
