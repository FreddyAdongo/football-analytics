# %%
import pandas as pd

# %%
player_url = 'https://fbref.com/en/players/55d492ba/scout/12271/Cortnee-Vine-Scouting-Report'

df = pd.read_html(player_url, attrs={'id': 'scout_summary_AM'})

# %%
#import packages
import matplotlib.pyplot as plt
from mplsoccer import PyPizza, FontManager

# %%
font_normal = FontManager('https://github.com/openmaptiles/fonts/blob/0bcd6431ec82fbb74b3a5b697ce315ebf795ad8e/roboto/Roboto-Regular.ttf')
font_bold = FontManager('https://github.com/openmaptiles/fonts/blob/0bcd6431ec82fbb74b3a5b697ce315ebf795ad8e/roboto/Roboto-Bold.ttf')

# %%
#add parameters and values
params = ["Non-Penalty Goals", "Assists", "Shot-Creating Actions",
         "Progressive Passes", "Progressive Carries", "Successful Take-Ons",
         "Tackles", "Interceptions", "Blocks"]

values = [98, 94, 98,
         83, 98, 94,
         65, 20, 91]

# %%
# color for the slices and text
slice_colors = ["#3182bd"] * 3 + ["#feb24c"] * 3 + ["#f03b20"] * 3
text_colors = ["#000000"] * 6 + ["#000000"] * 3

# instantiate PyPizza class
baker = PyPizza(
    params=params,                  # list of parameters
    background_color="#FFFAF0",     # background color
    straight_line_color="#EBEBE9",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=0,               # linewidth of last circle
    other_circle_lw=1,              # linewidth for other circles
    other_circle_ls="-.",
    inner_circle_size=6            # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(8, 8.5),                # adjust figsize according to your need
    color_blank_space="same",        # use same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        fontfamily='monospace', va="center"
    ),                               # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=11,
        fontfamily='monospace', zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="#3182bd",
            boxstyle="round,pad=0.2", lw=1
        )
    )                                # values to be used when adding parameter-values
)

# add title
fig.text(
    x=0.515, 
    y=0.975, 
    s="Cortnee Vine | Forward | Sydney FC", 
    size=16,
    ha="center", 
    va='center',
    fontfamily='monospace', color="#000000"
)

# add subtitle
fig.text(
    x=0.515, 
    y=0.930, 
    s="Percentile Stats in A-League Women | 2023-24",
    size=13,
    ha="center", 
    va="center",
    fontfamily='monospace', color="#000000"
)

# add credits
CREDIT_1 = "Data: FBREF"
CREDIT_2 = "Created by: @freddys_canvas"
fig.text(
    0.298, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
    fontfamily='monospace', color="#000000",
    ha="right"
)
# Out:
# Text(0.298, 0.02, 'Data: FBREF\nCreated by: @freddys_canvas')

# %%
#fig.savefig('C:/Users/fredd/OneDrive/Pictures/vine_pizza.png', dpi=300, bbox_inches='tight')
