# %%
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get(
    'https://www.sofascore.com/manchester-united-tottenham-hotspur/IsK#id:11352407,tab:statistics',
    headers={
         'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }
)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.select('g[cursor="pointer"]')
# Out:
# []

# %%
import requests


headers = {
    'authority': 'api.sofascore.com',
    'accept': '*/*',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cache-control': 'max-age=0',
    'if-none-match': 'W/"932bdb64a5"',
    'origin': 'https://www.sofascore.com',
    'referer': 'https://www.sofascore.com/',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

response = requests.get('https://api.sofascore.com/api/v1/event/11352407/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
headers['if-Modified-Since'] = 'Sun, 7 Jan 2024 00:00:00 EST'

# %%
response = requests.get('https://api.sofascore.com/api/v1/event/11352407/shotmap', headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
shots = response.json()

# %%
shots
# Out:
# {'shotmap': [{'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'free-kick',
#    'playerCoordinates': {'x': 30.197273238078516, 'y': 47, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'close-high',
#    'goalMouthCoordinates': {'x': 0, 'y': 73.24374410757775, 'z': 56.9},
#    'xg': 0.13315658271313,
#    'id': 2153766,
#    'time': 95,
#    'addedTime': 9,
#    'timeSeconds': 5915,
#    'draw': {'start': {'x': 47, 'y': 13.374625938803113},
#     'end': {'x': 24.157015243583416, 'y': 0},
#     'goal': {'x': 40.40766366981866, 'y': 76.68026413911397}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 385,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Casemiro',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'casemiro',
#     'shortName': 'Casemiro',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 77436,
#     'id': 122951,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كازيميرو'},
#      'shortNameTranslation': {'ar': 'كازيميرو'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 14.523012269335725,
#     'y': 46.691652484733964,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 84.12557165230342, 'z': 19},
#    'blockCoordinates': {'x': 4.409461438489348,
#     'y': 17.84282397665323,
#     'z': 0},
#    'xg': 0.019529964774847,
#    'id': 2153751,
#    'time': 86,
#    'addedTime': 7,
#    'timeSeconds': 5778,
#    'draw': {'start': {'x': 14.642264656142501, 'y': 18.210775532594752},
#     'block': {'x': 77.32443828129905, 'y': 6.146949794214327},
#     'end': {'x': 23.762446982552426, 'y': 0},
#     'goal': {'x': 83.56246716763872, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 522,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Casemiro',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'casemiro',
#     'shortName': 'Casemiro',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 77436,
#     'id': 122951,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كازيميرو'},
#      'shortNameTranslation': {'ar': 'كازيميرو'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 4.303754254955507,
#     'y': 34.891368155863766,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 57.22824925843939, 'z': 19},
#    'blockCoordinates': {'x': 2.416491094358486,
#     'y': 45.81214636890782,
#     'z': 0},
#    'xg': 0.047245837748051,
#    'id': 2153748,
#    'time': 88,
#    'addedTime': 6,
#    'timeSeconds': 5752,
#    'draw': {'start': {'x': 70.05259508248494, 'y': 23.873173592990092},
#     'block': {'x': 43.85158410576135, 'y': 5.824945125435603},
#     'end': {'x': 30.509884041211848, 'y': 0},
#     'goal': {'x': 29.250495409582243, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 548,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ben Davies',
#     'slug': 'ben-davies',
#     'shortName': 'B. Davies',
#     'position': 'D',
#     'jerseyNumber': '33',
#     'userCount': 2134,
#     'id': 94758,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ديفيز, بن'},
#      'shortNameTranslation': {'ar': 'ب. ديفيز'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 24, 'y': 69.6781220347201, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 0.55360088605849, 'z': 19},
#    'blockCoordinates': {'x': 26.12521030590002, 'y': 44, 'z': 0},
#    'xg': 0.011816093698144,
#    'id': 2153730,
#    'time': 83,
#    'addedTime': 3,
#    'timeSeconds': 5569,
#    'draw': {'start': {'x': 18.0576538060188, 'y': 24},
#     'block': {'x': 44, 'y': 22.937773214242327},
#     'end': {'x': 10.669206632865126, 'y': 0},
#     'goal': {'x': 86.0796374949954, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 731,
#    'incidentType': 'shot'},
#   {'player': {'name': 'James Maddison',
#     'slug': 'james-maddison',
#     'shortName': 'J. Maddison',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 16118,
#     'id': 356398,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماديسون, جيمس'},
#      'shortNameTranslation': {'ar': 'ج. ماديسون'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 11.766220984066885,
#     'y': 61.033176735190146,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 63.40599712156317, 'z': 19},
#    'blockCoordinates': {'x': 4.290838101164663,
#     'y': 53.353081054668486,
#     'z': 0},
#    'xg': 0.056831602007151,
#    'id': 2153721,
#    'time': 98,
#    'addedTime': 3,
#    'timeSeconds': 5568,
#    'draw': {'start': {'x': 10.117072759742925, 'y': 11.512336608818936},
#     'block': {'x': 21.873313906878572, 'y': 3.0578705278066387},
#     'end': {'x': 75.34650221567358, 'y': 0},
#     'goal': {'x': 3.1197106237946812, 'y': 81}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 732,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 23.921912081669063,
#     'y': 0.20850206104334745,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 37.90812822964803, 'z': 20.9},
#    'blockCoordinates': {'x': 1.9645500647736043,
#     'y': 72.49273612230297,
#     'z': 0},
#    'xg': 0.029450329020619,
#    'xgot': 0.0265,
#    'id': 2153712,
#    'time': 83,
#    'addedTime': 2,
#    'timeSeconds': 5466,
#    'draw': {'start': {'x': 61.417670858742724, 'y': 1.6212033093046792},
#     'block': {'x': 92.01202603304506, 'y': 2.4138024293039124},
#     'end': {'x': 95.83824422316212, 'y': 0},
#     'goal': {'x': 78.3288554870881, 'y': 92.15789740140627}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 834,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 12.45665513298647,
#     'y': 77.0669421330741,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 60.04149370081474, 'z': 19},
#    'blockCoordinates': {'x': 12.25619648337545, 'y': 23.1397512466349, 'z': 0},
#    'xg': 0.031864702701569,
#    'id': 2153661,
#    'time': 93,
#    'timeSeconds': 5111,
#    'draw': {'start': {'x': 75.44135617458139, 'y': 22.96095336485707},
#     'block': {'x': 86.64152064466273, 'y': 21.858200644365986},
#     'end': {'x': 28.49232298060305, 'y': 0},
#     'goal': {'x': 21.71720002373995, 'y': 81}},
#    'reversedPeriodTime': 5,
#    'reversedPeriodTimeSeconds': 289,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Lisandro Martínez',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'lisandro-martinez',
#     'shortName': 'L. Martínez',
#     'position': 'D',
#     'jerseyNumber': '6',
#     'userCount': 29946,
#     'id': 859999,
#     'fieldTranslations': {'nameTranslation': {'ar': 'مارتينيز، ليساندرو'},
#      'shortNameTranslation': {'ar': 'م. ليساندرو'}}},
#    'isHome': True,
#    'shotType': 'goal',
#    'goalType': 'own',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 3.154055896423107,
#     'y': 91.16668169991048,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 78.19738614278054, 'z': 1.3},
#    'id': 2153647,
#    'time': 77,
#    'timeSeconds': 4929,
#    'draw': {'start': {'x': 70.50401580954669, 'y': 6.772377557592573},
#     'end': {'x': 3.6007534576234406, 'y': 0},
#     'goal': {'x': 16.426069279598707, 'y': 100}},
#    'reversedPeriodTime': 8,
#    'reversedPeriodTimeSeconds': 471,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Ben Davies',
#     'slug': 'ben-davies',
#     'shortName': 'B. Davies',
#     'position': 'D',
#     'jerseyNumber': '33',
#     'userCount': 2134,
#     'id': 94758,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ديفيز, بن'},
#      'shortNameTranslation': {'ar': 'ب. ديفيز'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 5.693405583659123,
#     'y': 39.552930123210544,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'right',
#    'goalMouthCoordinates': {'x': 0, 'y': 41.505211104145594, 'z': 2.8},
#    'blockCoordinates': {'x': 5, 'y': 66.44963750543363, 'z': 0},
#    'xg': 0.41539064049721,
#    'id': 2153717,
#    'time': 77,
#    'timeSeconds': 4928,
#    'draw': {'start': {'x': 42.645057727910654, 'y': 4.801446318876588},
#     'block': {'x': 64.77025118589904, 'y': 5},
#     'end': {'x': 55.698313830297096, 'y': 0},
#     'goal': {'x': 7.685202435255718, 'y': 58.0221170531796}},
#    'reversedPeriodTime': 8,
#    'reversedPeriodTimeSeconds': 472,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Casemiro',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'casemiro',
#     'shortName': 'Casemiro',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 77436,
#     'id': 122951,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كازيميرو'},
#      'shortNameTranslation': {'ar': 'كازيميرو'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 20.033115029136543,
#     'y': 34.397020021465536,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 85.34430814251127, 'z': 6.3},
#    'blockCoordinates': {'x': 0.4093739778112022,
#     'y': 30.403477966627754,
#     'z': 0},
#    'xg': 0.05876436829567,
#    'xgot': 0.1292,
#    'id': 2153612,
#    'time': 83,
#    'timeSeconds': 4798,
#    'draw': {'start': {'x': 52.973997373230944, 'y': 18.343729663818973},
#     'block': {'x': 1.562054900839172, 'y': 0.9506481300332736},
#     'end': {'x': 89.72513732195546, 'y': 0},
#     'goal': {'x': 84.7975203224469, 'y': 100}},
#    'reversedPeriodTime': 11,
#    'reversedPeriodTimeSeconds': 602,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pape Matar Sarr',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'pape-matar-sarr',
#     'shortName': 'P. M. Sarr',
#     'position': 'M',
#     'jerseyNumber': '29',
#     'userCount': 10254,
#     'id': 1002711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سار، باب ماتار'},
#      'shortNameTranslation': {'ar': 'س. ب. ماتار'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 5.170023393733441,
#     'y': 38.81107120049277,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'left',
#    'goalMouthCoordinates': {'x': 0, 'y': 84.13744465621919, 'z': 6.9},
#    'blockCoordinates': {'x': 3.530408726280122,
#     'y': 11.174846092542131,
#     'z': 0},
#    'xg': 0.070206329226494,
#    'id': 2153575,
#    'time': 81,
#    'timeSeconds': 4407,
#    'draw': {'start': {'x': 26.21147688499331, 'y': 10.932950912911698},
#     'block': {'x': 7.318305264761884, 'y': 4.56269332460576},
#     'end': {'x': 0.7326469849173329, 'y': 0},
#     'goal': {'x': 0.29441293478715536, 'y': 5.219555413828971}},
#    'reversedPeriodTime': 17,
#    'reversedPeriodTimeSeconds': 993,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Yves Bissouma',
#     'slug': 'yves-bissouma',
#     'shortName': 'Y. Bissouma',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 6455,
#     'id': 844842,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بيسوما, إيف'},
#      'shortNameTranslation': {'ar': 'إ. بيسوما'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 16.235572399079917,
#     'y': 58.3137639433932,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'close-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 35.59551713769608, 'z': 5.6},
#    'xg': 0.043578382581472,
#    'id': 2153547,
#    'time': 63,
#    'timeSeconds': 3809,
#    'draw': {'start': {'x': 35.11485406423485, 'y': 18.73419704111765},
#     'end': {'x': 47.15203855942474, 'y': 0},
#     'goal': {'x': 20.928551395623956, 'y': 88.74706241973868}},
#    'reversedPeriodTime': 27,
#    'reversedPeriodTimeSeconds': 1591,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Heung-min Son',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'heung-min-son',
#     'shortName': 'H. M. Son',
#     'position': 'F',
#     'jerseyNumber': '7',
#     'userCount': 75607,
#     'id': 111505,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سون, هيونغ مين'},
#      'shortNameTranslation': {'ar': 'ه. م. سون'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 3.905675588561433,
#     'y': 0.9471554838519651,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 59.69649726537024, 'z': 19},
#    'blockCoordinates': {'x': 14.45935353379639,
#     'y': 65.59531696488413,
#     'z': 0},
#    'xg': 0.12914571166039,
#    'id': 2153527,
#    'time': 56,
#    'timeSeconds': 3648,
#    'draw': {'start': {'x': 21.831339690006594, 'y': 12.05802058454429},
#     'block': {'x': 17.16618890548429, 'y': 9.239865140136873},
#     'end': {'x': 71.9354401928063, 'y': 0},
#     'goal': {'x': 10.601567174114123, 'y': 81}},
#    'reversedPeriodTime': 30,
#    'reversedPeriodTimeSeconds': 1752,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Yves Bissouma',
#     'slug': 'yves-bissouma',
#     'shortName': 'Y. Bissouma',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 6455,
#     'id': 844842,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بيسوما, إيف'},
#      'shortNameTranslation': {'ar': 'إ. بيسوما'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 19.34069082111682, 'y': 100, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'close-high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.34417806481777, 'z': 56.9},
#    'xg': 0.025082988664508,
#    'id': 2153521,
#    'time': 63,
#    'timeSeconds': 3573,
#    'draw': {'start': {'x': 34.79721519433607, 'y': 11.651571396205195},
#     'end': {'x': 7.2727123446757815, 'y': 0},
#     'goal': {'x': 52.911201196739256, 'y': 59.26893312411024}},
#    'reversedPeriodTime': 31,
#    'reversedPeriodTimeSeconds': 1827,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Casemiro',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'casemiro',
#     'shortName': 'Casemiro',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 77436,
#     'id': 122951,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كازيميرو'},
#      'shortNameTranslation': {'ar': 'كازيميرو'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 0.8352038339794223,
#     'y': 26.45795607284404,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 35.021459814676646, 'z': 27.2},
#    'blockCoordinates': {'x': 1, 'y': 59.59655903986943, 'z': 0},
#    'xg': 0.22120563685894,
#    'xgot': 0.1599,
#    'id': 2153497,
#    'time': 53,
#    'timeSeconds': 3344,
#    'draw': {'start': {'x': 87.73526422623796, 'y': 8.443711063960865},
#     'block': {'x': 80.09765716522644, 'y': 1},
#     'end': {'x': 65.02879795883759, 'y': 0},
#     'goal': {'x': 2.7845747110676697, 'y': 100}},
#    'reversedPeriodTime': 35,
#    'reversedPeriodTimeSeconds': 2056,
#    'incidentType': 'shot'},
#   {'player': {'name': 'James Maddison',
#     'slug': 'james-maddison',
#     'shortName': 'J. Maddison',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 16118,
#     'id': 356398,
#     'fieldTranslations': {'nameTranslation': {'ar': 'ماديسون, جيمس'},
#      'shortNameTranslation': {'ar': 'ج. ماديسون'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 8, 'y': 33, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 59.67433515841975, 'z': 1.9},
#    'blockCoordinates': {'x': 0.8556671998155283,
#     'y': 85.65710752880932,
#     'z': 0},
#    'xg': 0.044568542391062,
#    'xgot': 0.2872,
#    'id': 2153483,
#    'time': 43,
#    'timeSeconds': 3177,
#    'draw': {'start': {'x': 33, 'y': 8},
#     'block': {'x': 75.23491461754699, 'y': 0.42237440972582685},
#     'end': {'x': 0.5162862351267705, 'y': 0},
#     'goal': {'x': 6.681298178289566, 'y': 21.776442117830598}},
#    'reversedPeriodTime': 38,
#    'reversedPeriodTimeSeconds': 2223,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Destiny Udogie',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'destiny-udogie',
#     'shortName': 'D. Udogie',
#     'position': 'D',
#     'jerseyNumber': '38',
#     'userCount': 4367,
#     'id': 983572,
#     'fieldTranslations': {'nameTranslation': {'ar': 'أودو جي ، إيينوما ديستني'},
#      'shortNameTranslation': {'ar': 'أ. ج. ، إ. ديستني'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 4.0566852104884665, 'y': 38, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 91.81549307930469, 'z': 1.9},
#    'blockCoordinates': {'x': 1.645871014412975, 'y': 68.1103352653823, 'z': 0},
#    'xg': 0.085355244576931,
#    'xgot': 0.3487,
#    'id': 2153467,
#    'time': 55,
#    'timeSeconds': 3087,
#    'draw': {'start': {'x': 38, 'y': 4.224635112995428},
#     'block': {'x': 77.3206882364297, 'y': 0.18867371662544674},
#     'end': {'x': 5.520849996774189, 'y': 0},
#     'goal': {'x': 61.07644574902929, 'y': 100}},
#    'reversedPeriodTime': 39,
#    'reversedPeriodTimeSeconds': 2313,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Antony',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'antony',
#     'shortName': 'Antony',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 59140,
#     'id': 958380,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سانتوس, أنتوني'},
#      'shortNameTranslation': {'ar': 'أ. سانتوس'}}},
#    'isHome': False,
#    'shotType': 'post',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 10.244993045309851,
#     'y': 74.14479063506133,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'left',
#    'goalMouthCoordinates': {'x': 0, 'y': 91.4767900637386, 'z': 18.4},
#    'xg': 0.14357167482376,
#    'id': 2153459,
#    'time': 46,
#    'timeSeconds': 3033,
#    'draw': {'start': {'x': 58.11756430210776, 'y': 24.20710227824067},
#     'end': {'x': 46.20276897196245, 'y': 0},
#     'goal': {'x': 32.32565026661181, 'y': 100}},
#    'reversedPeriodTime': 40,
#    'reversedPeriodTimeSeconds': 2367,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pape Matar Sarr',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'pape-matar-sarr',
#     'shortName': 'P. M. Sarr',
#     'position': 'M',
#     'jerseyNumber': '29',
#     'userCount': 10254,
#     'id': 1002711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سار، باب ماتار'},
#      'shortNameTranslation': {'ar': 'س. ب. ماتار'}}},
#    'isHome': True,
#    'shotType': 'goal',
#    'goalType': 'regular',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 3.4054206968649527,
#     'y': 60.061400994053855,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 55.60439941032148, 'z': 32.3},
#    'xg': 0.31675061583519,
#    'xgot': 0.9598,
#    'id': 2153453,
#    'time': 57,
#    'timeSeconds': 2919,
#    'draw': {'start': {'x': 74.85978653029896, 'y': 0.4770855262445517},
#     'end': {'x': 76.37953226188927, 'y': 0},
#     'goal': {'x': 22.600125441029306, 'y': 100}},
#    'reversedPeriodTime': 42,
#    'reversedPeriodTimeSeconds': 2481,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Cristian Romero',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'cristian-romero',
#     'shortName': 'C. Romero',
#     'position': 'D',
#     'jerseyNumber': '17',
#     'userCount': 20467,
#     'id': 829932,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كريستيان غابرييل روميرو'},
#      'shortNameTranslation': {'ar': 'ك. غ. روميرو'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 9, 'y': 79.29704554260749, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'close-high',
#    'goalMouthCoordinates': {'x': 0, 'y': 17.732510083688233, 'z': 50},
#    'blockCoordinates': {'x': 0.9815596950862142,
#     'y': 74.51862667738548,
#     'z': 0},
#    'xg': 0.11050827801228,
#    'id': 2153300,
#    'time': 51,
#    'timeSeconds': 2642,
#    'draw': {'start': {'x': 11.741147820080386, 'y': 9},
#     'block': {'x': 63.23384515749066, 'y': 5.055827838752213},
#     'end': {'x': 95.64910748108375, 'y': 0},
#     'goal': {'x': 45.50948150057203, 'y': 50}},
#    'reversedPeriodTime': 1,
#    'reversedPeriodTimeSeconds': 58,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Dejan Kulusevski',
#     'slug': 'dejan-kulusevski',
#     'shortName': 'D. Kulusevski',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 9718,
#     'id': 928124,
#     'fieldTranslations': {'nameTranslation': {'ar': 'دافيد زوغارو'},
#      'shortNameTranslation': {'ar': 'د. زوغارو'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 20.25657540303327, 'y': 74, 'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 46.43839945558096, 'z': 2.5},
#    'blockCoordinates': {'x': 0.9491291912890794,
#     'y': 46.13098792442721,
#     'z': 0},
#    'xg': 0.018085032701492,
#    'xgot': 0.0215,
#    'id': 2153290,
#    'time': 36,
#    'timeSeconds': 2580,
#    'draw': {'start': {'x': 74, 'y': 36.370262209096296},
#     'block': {'x': 96.49429601572177, 'y': 1.3386074489137978},
#     'end': {'x': 27.105201201250715, 'y': 0},
#     'goal': {'x': 48.06064516648245, 'y': 91.50331094835175}},
#    'reversedPeriodTime': 2,
#    'reversedPeriodTimeSeconds': 120,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pedro Porro',
#     'slug': 'pedro-porro',
#     'shortName': 'P. Porro',
#     'position': 'D',
#     'jerseyNumber': '23',
#     'userCount': 6474,
#     'id': 913654,
#     'fieldTranslations': {'nameTranslation': {'ar': 'بورو, بيدرو'},
#      'shortNameTranslation': {'ar': 'ب. بورو'}}},
#    'isHome': False,
#    'shotType': 'post',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 30.877371940850196, 'y': 52, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 55.393986075656144, 'z': 39.2},
#    'xg': 0.11045233905315,
#    'id': 2153268,
#    'time': 31,
#    'timeSeconds': 2368,
#    'draw': {'start': {'x': 52, 'y': 26.7502505370934},
#     'end': {'x': 0.13453838444070243, 'y': 0},
#     'goal': {'x': 34.38774210997717, 'y': 100}},
#    'reversedPeriodTime': 6,
#    'reversedPeriodTimeSeconds': 332,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 6, 'y': 5.0567054091792585, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 22.236790937421844, 'z': 58.3},
#    'xg': 0.52116453647614,
#    'id': 2153246,
#    'time': 31,
#    'timeSeconds': 2145,
#    'draw': {'start': {'x': 8.291646572516939, 'y': 6},
#     'end': {'x': 76.29887460936436, 'y': 0},
#     'goal': {'x': 52.96136948789865, 'y': 81.42947920993434}},
#    'reversedPeriodTime': 10,
#    'reversedPeriodTimeSeconds': 555,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Antony',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'antony',
#     'shortName': 'Antony',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 59140,
#     'id': 958380,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سانتوس, أنتوني'},
#      'shortNameTranslation': {'ar': 'أ. سانتوس'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 0.3713659338777049,
#     'y': 34.32938636912927,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 81.51619418908521, 'z': 72.2},
#    'xg': 0.018598780035973,
#    'id': 2153229,
#    'time': 29,
#    'timeSeconds': 1906,
#    'draw': {'start': {'x': 100, 'y': 11.774717258333595},
#     'end': {'x': 25.618884965829217, 'y': 0},
#     'goal': {'x': 67.10454519940365, 'y': 9.977041590077828}},
#    'reversedPeriodTime': 14,
#    'reversedPeriodTimeSeconds': 794,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 25.05631845230729,
#     'y': 48.01368773539872,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 22.336028175100523, 'z': 19},
#    'blockCoordinates': {'x': 23.989484227663876,
#     'y': 74.02091547744018,
#     'z': 0},
#    'xg': 0.05014044418931,
#    'id': 2153228,
#    'time': 41,
#    'timeSeconds': 1901,
#    'draw': {'start': {'x': 88.60521723092414, 'y': 1.5422746360797746},
#     'block': {'x': 78.58643212480058, 'y': 16.696046979898686},
#     'end': {'x': 35.52852118304902, 'y': 0},
#     'goal': {'x': 89.2128585661648, 'y': 81}},
#    'reversedPeriodTime': 14,
#    'reversedPeriodTimeSeconds': 799,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pape Matar Sarr',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'pape-matar-sarr',
#     'shortName': 'P. M. Sarr',
#     'position': 'M',
#     'jerseyNumber': '29',
#     'userCount': 10254,
#     'id': 1002711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سار، باب ماتار'},
#      'shortNameTranslation': {'ar': 'س. ب. ماتار'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'regular',
#    'playerCoordinates': {'x': 4, 'y': 37.90273258031019, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 22.390124753543347, 'z': 19},
#    'blockCoordinates': {'x': 2.5660019662651186,
#     'y': 74.56735982950971,
#     'z': 0},
#    'xg': 0.076226487755775,
#    'id': 2153219,
#    'time': 32,
#    'timeSeconds': 1782,
#    'draw': {'start': {'x': 4.224657234174671, 'y': 4},
#     'block': {'x': 59.36778839477709, 'y': 1.1996342772176343},
#     'end': {'x': 27.091622248581984, 'y': 0},
#     'goal': {'x': 9.056853022428335, 'y': 81}},
#    'reversedPeriodTime': 16,
#    'reversedPeriodTimeSeconds': 918,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pape Matar Sarr',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'pape-matar-sarr',
#     'shortName': 'P. M. Sarr',
#     'position': 'M',
#     'jerseyNumber': '29',
#     'userCount': 10254,
#     'id': 1002711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سار، باب ماتار'},
#      'shortNameTranslation': {'ar': 'س. ب. ماتار'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 11.065805036141468,
#     'y': 16.70669313790127,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 13.28736728277812, 'z': 10.8},
#    'blockCoordinates': {'x': 2.318240091905233,
#     'y': 37.194150044026465,
#     'z': 0},
#    'xg': 0.13673608005047,
#    'xgot': 0.0379,
#    'id': 2153214,
#    'time': 26,
#    'timeSeconds': 1780,
#    'draw': {'start': {'x': 73.93296247146053, 'y': 0.3915821124513581},
#     'block': {'x': 59.04266820218883, 'y': 2.0952009417856594},
#     'end': {'x': 34.426236258035246, 'y': 0},
#     'goal': {'x': 3.9251578439562564, 'y': 100}},
#    'reversedPeriodTime': 16,
#    'reversedPeriodTimeSeconds': 920,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Casemiro',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'casemiro',
#     'shortName': 'Casemiro',
#     'position': 'M',
#     'jerseyNumber': '18',
#     'userCount': 77436,
#     'id': 122951,
#     'fieldTranslations': {'nameTranslation': {'ar': 'كازيميرو'},
#      'shortNameTranslation': {'ar': 'كازيميرو'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 14.715751514364666, 'y': 53, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 12.280234962182007, 'z': 19},
#    'blockCoordinates': {'x': 7.482333017200723,
#     'y': 60.56742411246789,
#     'z': 0},
#    'xg': 0.045233175158501,
#    'id': 2153208,
#    'time': 23,
#    'timeSeconds': 1657,
#    'draw': {'start': {'x': 53, 'y': 0.09514262263248874},
#     'block': {'x': 23.09259167364455, 'y': 0.5719460281888082},
#     'end': {'x': 56.42181867925681, 'y': 0},
#     'goal': {'x': 26.535083439825932, 'y': 81}},
#    'reversedPeriodTime': 18,
#    'reversedPeriodTimeSeconds': 1043,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Alejandro Garnacho',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'alejandro-garnacho',
#     'shortName': 'A. Garnacho',
#     'position': 'M',
#     'jerseyNumber': '17',
#     'userCount': 50248,
#     'id': 1135873,
#     'fieldTranslations': {'nameTranslation': {'ar': 'Ferreyra, Alejandro Garnacho'},
#      'shortNameTranslation': {'ar': 'A. G. Ferreyra'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 15, 'y': 69.35861836973098, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 27.85913021862565, 'z': 19},
#    'blockCoordinates': {'x': 17.334771293002575,
#     'y': 9.00144117724404,
#     'z': 0},
#    'xg': 0.075864285230637,
#    'id': 2153197,
#    'time': 22,
#    'timeSeconds': 1543,
#    'draw': {'start': {'x': 1.3838978306813345, 'y': 15},
#     'block': {'x': 38.32926276974432, 'y': 14.148994174578856},
#     'end': {'x': 42.735249822371074, 'y': 0},
#     'goal': {'x': 9.724404411994058, 'y': 81}},
#    'reversedPeriodTime': 20,
#    'reversedPeriodTimeSeconds': 1157,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Dejan Kulusevski',
#     'slug': 'dejan-kulusevski',
#     'shortName': 'D. Kulusevski',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 9718,
#     'id': 928124,
#     'fieldTranslations': {'nameTranslation': {'ar': 'دافيد زوغارو'},
#      'shortNameTranslation': {'ar': 'د. زوغارو'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 12.79616367796729,
#     'y': 49.92443293236835,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 43.682248361212054, 'z': 1.9},
#    'blockCoordinates': {'x': 1.0372756778141055,
#     'y': 71.06586033397785,
#     'z': 0},
#    'xg': 0.056955367326736,
#    'xgot': 0.114,
#    'id': 2153190,
#    'time': 19,
#    'timeSeconds': 1466,
#    'draw': {'start': {'x': 100, 'y': 14.30741490172252},
#     'block': {'x': 100, 'y': 0.6614182968730811},
#     'end': {'x': 73.35535362970404, 'y': 0},
#     'goal': {'x': 11.60543530681921, 'y': 48.66583324483008}},
#    'reversedPeriodTime': 21,
#    'reversedPeriodTimeSeconds': 1234,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Bruno Fernandes',
#     'slug': 'bruno-fernandes',
#     'shortName': 'B. Fernandes',
#     'position': 'M',
#     'jerseyNumber': '8',
#     'userCount': 98559,
#     'id': 288205,
#     'fieldTranslations': {'nameTranslation': {'ar': 'برونو فيرنانديس'},
#      'shortNameTranslation': {'ar': 'ب. فيرنانديس'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 15, 'y': 64.23836898942665, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 55.31143655988331, 'z': 19},
#    'blockCoordinates': {'x': 1.9328421758684478, 'y': 46, 'z': 0},
#    'xg': 0.071688465774059,
#    'id': 2153191,
#    'time': 30,
#    'timeSeconds': 1428,
#    'draw': {'start': {'x': 59.312003357284674, 'y': 15},
#     'block': {'x': 46, 'y': 14.2756432082986},
#     'end': {'x': 96.40281327230986, 'y': 0},
#     'goal': {'x': 54.54931281793154, 'y': 81}},
#    'reversedPeriodTime': 22,
#    'reversedPeriodTimeSeconds': 1272,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Marcus Rashford',
#     'slug': 'marcus-rashford',
#     'shortName': 'M. Rashford',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 104521,
#     'id': 814590,
#     'fieldTranslations': {'nameTranslation': {'ar': 'راشفورد, ماركوس'},
#      'shortNameTranslation': {'ar': 'م. راشفورد'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 10.294524822742082, 'y': 100, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'close-high',
#    'goalMouthCoordinates': {'x': 0, 'y': 34.1742117853938, 'z': 55.6},
#    'xg': 0.24676975607872,
#    'id': 2153184,
#    'time': 21,
#    'timeSeconds': 1357,
#    'draw': {'start': {'x': 2.5510274035903464, 'y': 2.1187068506892555},
#     'end': {'x': 20.8473999141056, 'y': 0},
#     'goal': {'x': 33.50091093439925, 'y': 51.61960341890788}},
#    'reversedPeriodTime': 23,
#    'reversedPeriodTimeSeconds': 1343,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Marcus Rashford',
#     'slug': 'marcus-rashford',
#     'shortName': 'M. Rashford',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 104521,
#     'id': 814590,
#     'fieldTranslations': {'nameTranslation': {'ar': 'راشفورد, ماركوس'},
#      'shortNameTranslation': {'ar': 'م. راشفورد'}}},
#    'isHome': False,
#    'shotType': 'block',
#    'situation': 'set-piece',
#    'playerCoordinates': {'x': 11.50124837057603, 'y': 69, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 46.306949895471554, 'z': 19},
#    'blockCoordinates': {'x': 17.60312777869458, 'y': 67, 'z': 0},
#    'xg': 0.025442212820053,
#    'id': 2153174,
#    'time': 29,
#    'timeSeconds': 1223,
#    'draw': {'start': {'x': 69, 'y': 7.597766453781814},
#     'block': {'x': 67, 'y': 18.251655958685618},
#     'end': {'x': 38.3420009291229, 'y': 0},
#     'goal': {'x': 23.25350505785105, 'y': 81}},
#    'reversedPeriodTime': 25,
#    'reversedPeriodTimeSeconds': 1477,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Pape Matar Sarr',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'pape-matar-sarr',
#     'shortName': 'P. M. Sarr',
#     'position': 'M',
#     'jerseyNumber': '29',
#     'userCount': 10254,
#     'id': 1002711,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سار، باب ماتار'},
#      'shortNameTranslation': {'ar': 'س. ب. ماتار'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 7, 'y': 95.92319537409531, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 37, 'z': 84.7},
#    'xg': 0.046857692301273,
#    'id': 2153147,
#    'time': 18,
#    'timeSeconds': 928,
#    'draw': {'start': {'x': 79.46382771516579, 'y': 7},
#     'end': {'x': 63, 'y': 0},
#     'goal': {'x': 63, 'y': 24.70896941436585}},
#    'reversedPeriodTime': 30,
#    'reversedPeriodTimeSeconds': 1772,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Alejandro Garnacho',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'alejandro-garnacho',
#     'shortName': 'A. Garnacho',
#     'position': 'M',
#     'jerseyNumber': '17',
#     'userCount': 50248,
#     'id': 1135873,
#     'fieldTranslations': {'nameTranslation': {'ar': 'Ferreyra, Alejandro Garnacho'},
#      'shortNameTranslation': {'ar': 'A. G. Ferreyra'}}},
#    'isHome': True,
#    'shotType': 'block',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 16.12599445428304,
#     'y': 90.6593283188171,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 68.94151580061325, 'z': 19},
#    'blockCoordinates': {'x': 9.351605220250535,
#     'y': 25.000708996213696,
#     'z': 0},
#    'xg': 0.10797773301601,
#    'id': 2153140,
#    'time': 15,
#    'timeSeconds': 835,
#    'draw': {'start': {'x': 37.941697511315226, 'y': 13.80198787411597},
#     'block': {'x': 61.88363826495769, 'y': 0.4151430132956069},
#     'end': {'x': 90.27800861989925, 'y': 0},
#     'goal': {'x': 22.760213164723005, 'y': 81}},
#    'reversedPeriodTime': 32,
#    'reversedPeriodTimeSeconds': 1865,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Marcus Rashford',
#     'slug': 'marcus-rashford',
#     'shortName': 'M. Rashford',
#     'position': 'M',
#     'jerseyNumber': '10',
#     'userCount': 104521,
#     'id': 814590,
#     'fieldTranslations': {'nameTranslation': {'ar': 'راشفورد, ماركوس'},
#      'shortNameTranslation': {'ar': 'م. راشفورد'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 4.493362144432221,
#     'y': 22.362821437187073,
#     'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 92.47874951464283, 'z': 6.3},
#    'blockCoordinates': {'x': 1.4176745919005933, 'y': 100, 'z': 0},
#    'xg': 0.1181158721447,
#    'xgot': 0.9236,
#    'id': 2153132,
#    'time': 5,
#    'timeSeconds': 731,
#    'draw': {'start': {'x': 9.53840042554156, 'y': 0.5758222095724781},
#     'block': {'x': 11.456493286198246, 'y': 3.089060541335723},
#     'end': {'x': 68.302503072646, 'y': 0},
#     'goal': {'x': 53.4012859115223, 'y': 100}},
#    'reversedPeriodTime': 33,
#    'reversedPeriodTimeSeconds': 1969,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Raphaël Varane',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'raphael-varane',
#     'shortName': 'R. Varane',
#     'position': 'D',
#     'jerseyNumber': '19',
#     'userCount': 18319,
#     'id': 138310,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فاران, رافائيل'},
#      'shortNameTranslation': {'ar': 'ر. فاران'}}},
#    'isHome': False,
#    'shotType': 'miss',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 4.955178791154454, 'y': 41, 'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-left',
#    'goalMouthCoordinates': {'x': 0, 'y': 8.517458233507469, 'z': 70.8},
#    'xg': 0.020234361290932,
#    'id': 2153117,
#    'time': 2,
#    'timeSeconds': 567,
#    'draw': {'start': {'x': 41, 'y': 5.023431601716549},
#     'end': {'x': 42.27754129909319, 'y': 0},
#     'goal': {'x': 56.20059610924456, 'y': 49.30064856734529}},
#    'reversedPeriodTime': 36,
#    'reversedPeriodTimeSeconds': 2133,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Raphaël Varane',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'raphael-varane',
#     'shortName': 'R. Varane',
#     'position': 'D',
#     'jerseyNumber': '19',
#     'userCount': 18319,
#     'id': 138310,
#     'fieldTranslations': {'nameTranslation': {'ar': 'فاران, رافائيل'},
#      'shortNameTranslation': {'ar': 'ر. فاران'}}},
#    'isHome': True,
#    'shotType': 'save',
#    'situation': 'corner',
#    'playerCoordinates': {'x': 7.5920531237540185,
#     'y': 84.84905013965404,
#     'z': 0},
#    'bodyPart': 'head',
#    'goalMouthLocation': 'high-centre',
#    'goalMouthCoordinates': {'x': 0, 'y': 1.3798910567270326, 'z': 37.3},
#    'blockCoordinates': {'x': 1.8462343070363292,
#     'y': 40.906801802548195,
#     'z': 0},
#    'xg': 0.010620106011629,
#    'xgot': 0.0628,
#    'id': 2153115,
#    'time': 17,
#    'timeSeconds': 532,
#    'draw': {'start': {'x': 73.99580939708433, 'y': 21.32827759415408},
#     'block': {'x': 60.262003532595635, 'y': 0.41349517211841413},
#     'end': {'x': 52.80830060098791, 'y': 0},
#     'goal': {'x': 8.318245468981878, 'y': 28.514530751436567}},
#    'reversedPeriodTime': 37,
#    'reversedPeriodTimeSeconds': 2168,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Alejandro Garnacho',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'alejandro-garnacho',
#     'shortName': 'A. Garnacho',
#     'position': 'M',
#     'jerseyNumber': '17',
#     'userCount': 50248,
#     'id': 1135873,
#     'fieldTranslations': {'nameTranslation': {'ar': 'Ferreyra, Alejandro Garnacho'},
#      'shortNameTranslation': {'ar': 'A. G. Ferreyra'}}},
#    'isHome': False,
#    'shotType': 'save',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 10.789733049208742, 'y': 31, 'z': 0},
#    'bodyPart': 'right-foot',
#    'goalMouthLocation': 'low-right',
#    'goalMouthCoordinates': {'x': 0, 'y': 62.48349537142506, 'z': 1.9},
#    'blockCoordinates': {'x': 1.4996183201963573,
#     'y': 78.02715809375029,
#     'z': 0},
#    'xg': 0.022403502836823,
#    'xgot': 0.158,
#    'id': 2153099,
#    'time': 7,
#    'timeSeconds': 247,
#    'draw': {'start': {'x': 31, 'y': 8.079398939714498},
#     'block': {'x': 28.165263653436682, 'y': 0.2717341891846332},
#     'end': {'x': 84.908569618537, 'y': 0},
#     'goal': {'x': 30.631084108847396, 'y': 100}},
#    'reversedPeriodTime': 41,
#    'reversedPeriodTimeSeconds': 2453,
#    'incidentType': 'shot'},
#   {'player': {'name': 'Antony',
#     'firstName': '',
#     'lastName': '',
#     'slug': 'antony',
#     'shortName': 'Antony',
#     'position': 'M',
#     'jerseyNumber': '21',
#     'userCount': 59140,
#     'id': 958380,
#     'fieldTranslations': {'nameTranslation': {'ar': 'سانتوس, أنتوني'},
#      'shortNameTranslation': {'ar': 'أ. سانتوس'}}},
#    'isHome': True,
#    'shotType': 'miss',
#    'situation': 'assisted',
#    'playerCoordinates': {'x': 17.25598795330421,
#     'y': 23.373620616570896,
#     'z': 0},
#    'bodyPart': 'left-foot',
#    'goalMouthLocation': 'high',
#    'goalMouthCoordinates': {'x': 0, 'y': 47.062498285344965, 'z': 66.7},
#    'xg': 0.048655610531569,
#    'id': 2153091,
#    'time': -4,
#    'timeSeconds': 122,
#    'draw': {'start': {'x': 30.591292466187817, 'y': 1.4749294470933396},
#     'end': {'x': 82.63691936687164, 'y': 0},
#     'goal': {'x': 36.448613089938256, 'y': 32.16915689864926}},
#    'reversedPeriodTime': 43,
#    'reversedPeriodTimeSeconds': 2578,
#    'incidentType': 'shot'}]}

# %%
# Extracting the 'shotmap' data
shotmap_data = shots['shotmap']

# Converting to DataFrame
df = pd.DataFrame(shotmap_data)

# Displaying the DataFrame
print(df)
# Out:
#                                                player  isHome shotType  \
# 0   {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False     miss
# 1   {'name': 'Casemiro', 'firstName': '', 'lastNam...   False    block
# 2   {'name': 'Casemiro', 'firstName': '', 'lastNam...    True    block
# 3   {'name': 'Ben Davies', 'slug': 'ben-davies', '...   False    block
# 4   {'name': 'James Maddison', 'slug': 'james-madd...   False    block
# 5   {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False     save
# 6   {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False    block
# 7   {'name': 'Lisandro Martínez', 'firstName': '',...    True     goal
# 8   {'name': 'Ben Davies', 'slug': 'ben-davies', '...    True     miss
# 9   {'name': 'Casemiro', 'firstName': '', 'lastNam...    True     save
# 10  {'name': 'Pape Matar Sarr', 'firstName': '', '...    True     miss
# 11  {'name': 'Yves Bissouma', 'slug': 'yves-bissou...   False     miss
# 12  {'name': 'Heung-min Son', 'firstName': '', 'la...   False    block
# 13  {'name': 'Yves Bissouma', 'slug': 'yves-bissou...   False     miss
# 14  {'name': 'Casemiro', 'firstName': '', 'lastNam...    True     save
# 15  {'name': 'James Maddison', 'slug': 'james-madd...    True     save
# 16  {'name': 'Destiny Udogie', 'firstName': '', 'l...   False     save
# 17  {'name': 'Antony', 'firstName': '', 'lastName'...   False     post
# 18  {'name': 'Pape Matar Sarr', 'firstName': '', '...    True     goal
# 19  {'name': 'Cristian Romero', 'firstName': '', '...   False     miss
# 20  {'name': 'Dejan Kulusevski', 'slug': 'dejan-ku...    True     save
# 21  {'name': 'Pedro Porro', 'slug': 'pedro-porro',...   False     post
# 22  {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False     miss
# 23  {'name': 'Antony', 'firstName': '', 'lastName'...    True     miss
# 24  {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False    block
# 25  {'name': 'Pape Matar Sarr', 'firstName': '', '...    True    block
# 26  {'name': 'Pape Matar Sarr', 'firstName': '', '...   False     save
# 27  {'name': 'Casemiro', 'firstName': '', 'lastNam...   False    block
# 28  {'name': 'Alejandro Garnacho', 'firstName': ''...   False    block
# 29  {'name': 'Dejan Kulusevski', 'slug': 'dejan-ku...    True     save
# 30  {'name': 'Bruno Fernandes', 'slug': 'bruno-fer...   False    block
# 31  {'name': 'Marcus Rashford', 'slug': 'marcus-ra...   False     miss
# 32  {'name': 'Marcus Rashford', 'slug': 'marcus-ra...   False    block
# 33  {'name': 'Pape Matar Sarr', 'firstName': '', '...    True     miss
# 34  {'name': 'Alejandro Garnacho', 'firstName': ''...    True    block
# 35  {'name': 'Marcus Rashford', 'slug': 'marcus-ra...    True     save
# 36  {'name': 'Raphaël Varane', 'firstName': '', 'l...   False     miss
# 37  {'name': 'Raphaël Varane', 'firstName': '', 'l...    True     save
# 38  {'name': 'Alejandro Garnacho', 'firstName': ''...   False     save
# 39  {'name': 'Antony', 'firstName': '', 'lastName'...    True     miss
#
#     situation                                  playerCoordinates    bodyPart  \
# 0   free-kick         {'x': 30.197273238078516, 'y': 47, 'z': 0}  right-foot
# 1      corner  {'x': 14.523012269335725, 'y': 46.691652484733...        head
# 2    assisted  {'x': 4.303754254955507, 'y': 34.8913681558637...   left-foot
# 3     regular           {'x': 24, 'y': 69.6781220347201, 'z': 0}  right-foot
# 4    assisted  {'x': 11.766220984066885, 'y': 61.033176735190...  right-foot
# 5    assisted  {'x': 23.921912081669063, 'y': 0.2085020610433...  right-foot
# 6    assisted  {'x': 12.45665513298647, 'y': 77.0669421330741...  right-foot
# 7     regular  {'x': 3.154055896423107, 'y': 91.1666816999104...  right-foot
# 8    assisted  {'x': 5.693405583659123, 'y': 39.5529301232105...   left-foot
# 9     regular  {'x': 20.033115029136543, 'y': 34.397020021465...  right-foot
# 10     corner  {'x': 5.170023393733441, 'y': 38.8110712004927...        head
# 11   assisted  {'x': 16.235572399079917, 'y': 58.313763943393...  right-foot
# 12   assisted  {'x': 3.905675588561433, 'y': 0.94715548385196...  right-foot
# 13   assisted         {'x': 19.34069082111682, 'y': 100, 'z': 0}  right-foot
# 14  set-piece  {'x': 0.8352038339794223, 'y': 26.457956072844...        head
# 15    regular                          {'x': 8, 'y': 33, 'z': 0}  right-foot
# 16   assisted         {'x': 4.0566852104884665, 'y': 38, 'z': 0}   left-foot
# 17   assisted  {'x': 10.244993045309851, 'y': 74.144790635061...   left-foot
# 18    regular  {'x': 3.4054206968649527, 'y': 60.061400994053...   left-foot
# 19  set-piece           {'x': 9, 'y': 79.29704554260749, 'z': 0}        head
# 20   assisted          {'x': 20.25657540303327, 'y': 74, 'z': 0}   left-foot
# 21   assisted         {'x': 30.877371940850196, 'y': 52, 'z': 0}  right-foot
# 22   assisted          {'x': 6, 'y': 5.0567054091792585, 'z': 0}        head
# 23    regular  {'x': 0.3713659338777049, 'y': 34.329386369129...   left-foot
# 24   assisted  {'x': 25.05631845230729, 'y': 48.0136877353987...  right-foot
# 25    regular           {'x': 4, 'y': 37.90273258031019, 'z': 0}  right-foot
# 26   assisted  {'x': 11.065805036141468, 'y': 16.706693137901...   left-foot
# 27     corner         {'x': 14.715751514364666, 'y': 53, 'z': 0}        head
# 28   assisted          {'x': 15, 'y': 69.35861836973098, 'z': 0}  right-foot
# 29   assisted  {'x': 12.79616367796729, 'y': 49.9244329323683...   left-foot
# 30   assisted          {'x': 15, 'y': 64.23836898942665, 'z': 0}  right-foot
# 31   assisted        {'x': 10.294524822742082, 'y': 100, 'z': 0}        head
# 32  set-piece          {'x': 11.50124837057603, 'y': 69, 'z': 0}  right-foot
# 33     corner           {'x': 7, 'y': 95.92319537409531, 'z': 0}        head
# 34   assisted  {'x': 16.12599445428304, 'y': 90.6593283188171...  right-foot
# 35   assisted  {'x': 4.493362144432221, 'y': 22.3628214371870...  right-foot
# 36     corner          {'x': 4.955178791154454, 'y': 41, 'z': 0}        head
# 37     corner  {'x': 7.5920531237540185, 'y': 84.849050139654...        head
# 38   assisted         {'x': 10.789733049208742, 'y': 31, 'z': 0}  right-foot
# 39   assisted  {'x': 17.25598795330421, 'y': 23.3736206165708...   left-foot
#
#    goalMouthLocation                          goalMouthCoordinates        xg  \
# 0         close-high   {'x': 0, 'y': 73.24374410757775, 'z': 56.9}  0.133157
# 1           low-left     {'x': 0, 'y': 84.12557165230342, 'z': 19}  0.019530
# 2         low-centre     {'x': 0, 'y': 57.22824925843939, 'z': 19}  0.047246
# 3         low-centre      {'x': 0, 'y': 0.55360088605849, 'z': 19}  0.011816
# 4           low-left     {'x': 0, 'y': 63.40599712156317, 'z': 19}  0.056832
# 5        high-centre   {'x': 0, 'y': 37.90812822964803, 'z': 20.9}  0.029450
# 6         low-centre     {'x': 0, 'y': 60.04149370081474, 'z': 19}  0.031865
# 7         low-centre    {'x': 0, 'y': 78.19738614278054, 'z': 1.3}       NaN
# 8              right   {'x': 0, 'y': 41.505211104145594, 'z': 2.8}  0.415391
# 9           low-left    {'x': 0, 'y': 85.34430814251127, 'z': 6.3}  0.058764
# 10              left    {'x': 0, 'y': 84.13744465621919, 'z': 6.9}  0.070206
# 11        close-left    {'x': 0, 'y': 35.59551713769608, 'z': 5.6}  0.043578
# 12         low-right     {'x': 0, 'y': 59.69649726537024, 'z': 19}  0.129146
# 13  close-high-right   {'x': 0, 'y': 47.34417806481777, 'z': 56.9}  0.025083
# 14       high-centre  {'x': 0, 'y': 35.021459814676646, 'z': 27.2}  0.221206
# 15          low-left    {'x': 0, 'y': 59.67433515841975, 'z': 1.9}  0.044569
# 16          low-left    {'x': 0, 'y': 91.81549307930469, 'z': 1.9}  0.085355
# 17              left    {'x': 0, 'y': 91.4767900637386, 'z': 18.4}  0.143572
# 18       high-centre   {'x': 0, 'y': 55.60439941032148, 'z': 32.3}  0.316751
# 19        close-high    {'x': 0, 'y': 17.732510083688233, 'z': 50}  0.110508
# 20        low-centre    {'x': 0, 'y': 46.43839945558096, 'z': 2.5}  0.018085
# 21              high  {'x': 0, 'y': 55.393986075656144, 'z': 39.2}  0.110452
# 22         high-left  {'x': 0, 'y': 22.236790937421844, 'z': 58.3}  0.521165
# 23         high-left   {'x': 0, 'y': 81.51619418908521, 'z': 72.2}  0.018599
# 24        low-centre    {'x': 0, 'y': 22.336028175100523, 'z': 19}  0.050140
# 25        low-centre    {'x': 0, 'y': 22.390124753543347, 'z': 19}  0.076226
# 26        low-centre   {'x': 0, 'y': 13.28736728277812, 'z': 10.8}  0.136736
# 27        low-centre    {'x': 0, 'y': 12.280234962182007, 'z': 19}  0.045233
# 28        low-centre     {'x': 0, 'y': 27.85913021862565, 'z': 19}  0.075864
# 29        low-centre   {'x': 0, 'y': 43.682248361212054, 'z': 1.9}  0.056955
# 30        low-centre     {'x': 0, 'y': 55.31143655988331, 'z': 19}  0.071688
# 31        close-high    {'x': 0, 'y': 34.1742117853938, 'z': 55.6}  0.246770
# 32         low-right    {'x': 0, 'y': 46.306949895471554, 'z': 19}  0.025442
# 33        high-right                  {'x': 0, 'y': 37, 'z': 84.7}  0.046858
# 34        low-centre     {'x': 0, 'y': 68.94151580061325, 'z': 19}  0.107978
# 35          low-left    {'x': 0, 'y': 92.47874951464283, 'z': 6.3}  0.118116
# 36         high-left   {'x': 0, 'y': 8.517458233507469, 'z': 70.8}  0.020234
# 37       high-centre  {'x': 0, 'y': 1.3798910567270326, 'z': 37.3}  0.010620
# 38         low-right    {'x': 0, 'y': 62.48349537142506, 'z': 1.9}  0.022404
# 39              high  {'x': 0, 'y': 47.062498285344965, 'z': 66.7}  0.048656
#
#          id  time  addedTime  timeSeconds  \
# 0   2153766    95        9.0         5915
# 1   2153751    86        7.0         5778
# 2   2153748    88        6.0         5752
# 3   2153730    83        3.0         5569
# 4   2153721    98        3.0         5568
# 5   2153712    83        2.0         5466
# 6   2153661    93        NaN         5111
# 7   2153647    77        NaN         4929
# 8   2153717    77        NaN         4928
# 9   2153612    83        NaN         4798
# 10  2153575    81        NaN         4407
# 11  2153547    63        NaN         3809
# 12  2153527    56        NaN         3648
# 13  2153521    63        NaN         3573
# 14  2153497    53        NaN         3344
# 15  2153483    43        NaN         3177
# 16  2153467    55        NaN         3087
# 17  2153459    46        NaN         3033
# 18  2153453    57        NaN         2919
# 19  2153300    51        NaN         2642
# 20  2153290    36        NaN         2580
# 21  2153268    31        NaN         2368
# 22  2153246    31        NaN         2145
# 23  2153229    29        NaN         1906
# 24  2153228    41        NaN         1901
# 25  2153219    32        NaN         1782
# 26  2153214    26        NaN         1780
# 27  2153208    23        NaN         1657
# 28  2153197    22        NaN         1543
# 29  2153190    19        NaN         1466
# 30  2153191    30        NaN         1428
# 31  2153184    21        NaN         1357
# 32  2153174    29        NaN         1223
# 33  2153147    18        NaN          928
# 34  2153140    15        NaN          835
# 35  2153132     5        NaN          731
# 36  2153117     2        NaN          567
# 37  2153115    17        NaN          532
# 38  2153099     7        NaN          247
# 39  2153091    -4        NaN          122
#
#                                                  draw  reversedPeriodTime  \
# 0   {'start': {'x': 47, 'y': 13.374625938803113}, ...                   1
# 1   {'start': {'x': 14.642264656142501, 'y': 18.21...                   1
# 2   {'start': {'x': 70.05259508248494, 'y': 23.873...                   1
# 3   {'start': {'x': 18.0576538060188, 'y': 24}, 'b...                   1
# 4   {'start': {'x': 10.117072759742925, 'y': 11.51...                   1
# 5   {'start': {'x': 61.417670858742724, 'y': 1.621...                   1
# 6   {'start': {'x': 75.44135617458139, 'y': 22.960...                   5
# 7   {'start': {'x': 70.50401580954669, 'y': 6.7723...                   8
# 8   {'start': {'x': 42.645057727910654, 'y': 4.801...                   8
# 9   {'start': {'x': 52.973997373230944, 'y': 18.34...                  11
# 10  {'start': {'x': 26.21147688499331, 'y': 10.932...                  17
# 11  {'start': {'x': 35.11485406423485, 'y': 18.734...                  27
# 12  {'start': {'x': 21.831339690006594, 'y': 12.05...                  30
# 13  {'start': {'x': 34.79721519433607, 'y': 11.651...                  31
# 14  {'start': {'x': 87.73526422623796, 'y': 8.4437...                  35
# 15  {'start': {'x': 33, 'y': 8}, 'block': {'x': 75...                  38
# 16  {'start': {'x': 38, 'y': 4.224635112995428}, '...                  39
# 17  {'start': {'x': 58.11756430210776, 'y': 24.207...                  40
# 18  {'start': {'x': 74.85978653029896, 'y': 0.4770...                  42
# 19  {'start': {'x': 11.741147820080386, 'y': 9}, '...                   1
# 20  {'start': {'x': 74, 'y': 36.370262209096296}, ...                   2
# 21  {'start': {'x': 52, 'y': 26.7502505370934}, 'e...                   6
# 22  {'start': {'x': 8.291646572516939, 'y': 6}, 'e...                  10
# 23  {'start': {'x': 100, 'y': 11.774717258333595},...                  14
# 24  {'start': {'x': 88.60521723092414, 'y': 1.5422...                  14
# 25  {'start': {'x': 4.224657234174671, 'y': 4}, 'b...                  16
# 26  {'start': {'x': 73.93296247146053, 'y': 0.3915...                  16
# 27  {'start': {'x': 53, 'y': 0.09514262263248874},...                  18
# 28  {'start': {'x': 1.3838978306813345, 'y': 15}, ...                  20
# 29  {'start': {'x': 100, 'y': 14.30741490172252}, ...                  21
# 30  {'start': {'x': 59.312003357284674, 'y': 15}, ...                  22
# 31  {'start': {'x': 2.5510274035903464, 'y': 2.118...                  23
# 32  {'start': {'x': 69, 'y': 7.597766453781814}, '...                  25
# 33  {'start': {'x': 79.46382771516579, 'y': 7}, 'e...                  30
# 34  {'start': {'x': 37.941697511315226, 'y': 13.80...                  32
# 35  {'start': {'x': 9.53840042554156, 'y': 0.57582...                  33
# 36  {'start': {'x': 41, 'y': 5.023431601716549}, '...                  36
# 37  {'start': {'x': 73.99580939708433, 'y': 21.328...                  37
# 38  {'start': {'x': 31, 'y': 8.079398939714498}, '...                  41
# 39  {'start': {'x': 30.591292466187817, 'y': 1.474...                  43
#
#     reversedPeriodTimeSeconds incidentType  \
# 0                         385         shot
# 1                         522         shot
# 2                         548         shot
# 3                         731         shot
# 4                         732         shot
# 5                         834         shot
# 6                         289         shot
# 7                         471         shot
# 8                         472         shot
# 9                         602         shot
# 10                        993         shot
# 11                       1591         shot
# 12                       1752         shot
# 13                       1827         shot
# 14                       2056         shot
# 15                       2223         shot
# 16                       2313         shot
# 17                       2367         shot
# 18                       2481         shot
# 19                         58         shot
# 20                        120         shot
# 21                        332         shot
# 22                        555         shot
# 23                        794         shot
# 24                        799         shot
# 25                        918         shot
# 26                        920         shot
# 27                       1043         shot
# 28                       1157         shot
# 29                       1234         shot
# 30                       1272         shot
# 31                       1343         shot
# 32                       1477         shot
# 33                       1772         shot
# 34                       1865         shot
# 35                       1969         shot
# 36                       2133         shot
# 37                       2168         shot
# 38                       2453         shot
# 39                       2578         shot
#
#                                      blockCoordinates    xgot goalType
# 0                                                 NaN     NaN      NaN
# 1   {'x': 4.409461438489348, 'y': 17.8428239766532...     NaN      NaN
# 2   {'x': 2.416491094358486, 'y': 45.8121463689078...     NaN      NaN
# 3           {'x': 26.12521030590002, 'y': 44, 'z': 0}     NaN      NaN
# 4   {'x': 4.290838101164663, 'y': 53.3530810546684...     NaN      NaN
# 5   {'x': 1.9645500647736043, 'y': 72.492736122302...  0.0265      NaN
# 6   {'x': 12.25619648337545, 'y': 23.1397512466349...     NaN      NaN
# 7                                                 NaN     NaN      own
# 8            {'x': 5, 'y': 66.44963750543363, 'z': 0}     NaN      NaN
# 9   {'x': 0.4093739778112022, 'y': 30.403477966627...  0.1292      NaN
# 10  {'x': 3.530408726280122, 'y': 11.1748460925421...     NaN      NaN
# 11                                                NaN     NaN      NaN
# 12  {'x': 14.45935353379639, 'y': 65.5953169648841...     NaN      NaN
# 13                                                NaN     NaN      NaN
# 14           {'x': 1, 'y': 59.59655903986943, 'z': 0}  0.1599      NaN
# 15  {'x': 0.8556671998155283, 'y': 85.657107528809...  0.2872      NaN
# 16  {'x': 1.645871014412975, 'y': 68.1103352653823...  0.3487      NaN
# 17                                                NaN     NaN      NaN
# 18                                                NaN  0.9598  regular
# 19  {'x': 0.9815596950862142, 'y': 74.518626677385...     NaN      NaN
# 20  {'x': 0.9491291912890794, 'y': 46.130987924427...  0.0215      NaN
# 21                                                NaN     NaN      NaN
# 22                                                NaN     NaN      NaN
# 23                                                NaN     NaN      NaN
# 24  {'x': 23.989484227663876, 'y': 74.020915477440...     NaN      NaN
# 25  {'x': 2.5660019662651186, 'y': 74.567359829509...     NaN      NaN
# 26  {'x': 2.318240091905233, 'y': 37.1941500440264...  0.0379      NaN
# 27  {'x': 7.482333017200723, 'y': 60.5674241124678...     NaN      NaN
# 28  {'x': 17.334771293002575, 'y': 9.0014411772440...     NaN      NaN
# 29  {'x': 1.0372756778141055, 'y': 71.065860333977...  0.1140      NaN
# 30         {'x': 1.9328421758684478, 'y': 46, 'z': 0}     NaN      NaN
# 31                                                NaN     NaN      NaN
# 32          {'x': 17.60312777869458, 'y': 67, 'z': 0}     NaN      NaN
# 33                                                NaN     NaN      NaN
# 34  {'x': 9.351605220250535, 'y': 25.0007089962136...     NaN      NaN
# 35        {'x': 1.4176745919005933, 'y': 100, 'z': 0}  0.9236      NaN
# 36                                                NaN     NaN      NaN
# 37  {'x': 1.8462343070363292, 'y': 40.906801802548...  0.0628      NaN
# 38  {'x': 1.4996183201963573, 'y': 78.027158093750...  0.1580      NaN
# 39                                                NaN     NaN      NaN

# %%
selected_columns = [
    {'Player': item['player']['name'],
     'Outcome': item['shotType'],
     'Coordinates X': item['playerCoordinates']['x'],
     'Coordinates Y': item['playerCoordinates']['y'],
     'Team_id': item['id'],
     #'xg': item['xg'],
     'Shot Location': item['goalMouthLocation']}
    for item in shotmap_data if item.get('isHome', True)  
]

df = pd.DataFrame(selected_columns)
print(df)
# Out:
#                 Player Outcome  Coordinates X  Coordinates Y  Team_id  \
# 0             Casemiro   block       4.303754      34.891368  2153748
# 1    Lisandro Martínez    goal       3.154056      91.166682  2153647
# 2           Ben Davies    miss       5.693406      39.552930  2153717
# 3             Casemiro    save      20.033115      34.397020  2153612
# 4      Pape Matar Sarr    miss       5.170023      38.811071  2153575
# 5             Casemiro    save       0.835204      26.457956  2153497
# 6       James Maddison    save       8.000000      33.000000  2153483
# 7      Pape Matar Sarr    goal       3.405421      60.061401  2153453
# 8     Dejan Kulusevski    save      20.256575      74.000000  2153290
# 9               Antony    miss       0.371366      34.329386  2153229
# 10     Pape Matar Sarr   block       4.000000      37.902733  2153219
# 11    Dejan Kulusevski    save      12.796164      49.924433  2153190
# 12     Pape Matar Sarr    miss       7.000000      95.923195  2153147
# 13  Alejandro Garnacho   block      16.125994      90.659328  2153140
# 14     Marcus Rashford    save       4.493362      22.362821  2153132
# 15      Raphaël Varane    save       7.592053      84.849050  2153115
# 16              Antony    miss      17.255988      23.373621  2153091
#
#    Shot Location
# 0     low-centre
# 1     low-centre
# 2          right
# 3       low-left
# 4           left
# 5    high-centre
# 6       low-left
# 7    high-centre
# 8     low-centre
# 9      high-left
# 10    low-centre
# 11    low-centre
# 12    high-right
# 13    low-centre
# 14      low-left
# 15   high-centre
# 16          high

# %%
#Shotmap
import matplotlib.pyplot as plt

from mplsoccer import Pitch

# %%
pitch = Pitch(pitch_color='#22312b', line_color='white')
fig, ax = pitch.draw()

plt.gca().invert_xaxis()
plt.scatter(df['Coordinates X'], df['Coordinates Y'], df[''], c="#ea6969",s=70,alpha=1)

plt.title("Tottenham Shots vs Manchester United - 2023", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Manchester United vs Tottenham shots - 2023')
